# %%
from kubernetes import client, config

# Configs can be set in Configuration class directly or using helper utility
config.load_kube_config()

v1 = client.CoreV1Api()
print("Listing pods with their IPs:")
ret = v1.list_namespaced_pod("media-microservices")
for i in ret.items:
    print("%s\t%s\t%s" % (i.status.pod_ip, i.metadata.namespace, i.metadata.name))
# Out:
# Listing pods with their IPs:
# 10.244.0.4	media-microservices	cast-info-memcached-56b648cb4-274nc
# 10.244.0.34	media-microservices	cast-info-mongodb-566f5887c-vqzp6
# 10.244.0.18	media-microservices	cast-info-service-7ccdbff8-zf45m
# 10.244.0.32	media-microservices	compose-review-memcached-598d9dc6cd-cq2dm
# 10.244.0.5	media-microservices	compose-review-service-76ccb99f59-dgdcn
# 10.244.0.7	media-microservices	jaeger-58bb7ff659-vs6dh
# 10.244.0.22	media-microservices	movie-id-memcached-d5c78ff8d-qv8sz
# 10.244.0.12	media-microservices	movie-id-mongodb-75479f887f-ktrb5
# 10.244.0.8	media-microservices	movie-id-service-7d8d47875b-bdz9c
# 10.244.0.23	media-microservices	movie-info-memcached-6d87c6f986-x25jz
# 10.244.0.19	media-microservices	movie-info-mongodb-7667c59cb8-tmhrf
# 10.244.0.16	media-microservices	movie-info-service-558585d447-55dfn
# 10.244.0.3	media-microservices	movie-review-mongodb-7d4cdd95d8-bw2fx
# 10.244.0.10	media-microservices	movie-review-redis-6d9595df9f-7bb7z
# 10.244.0.13	media-microservices	movie-review-service-5cd6f6586c-v67md
# 10.244.0.20	media-microservices	nginx-web-server-5f7b5f45c4-nbpkz
# 10.244.0.35	media-microservices	page-service-54b69789b-6zgfz
# 10.244.0.14	media-microservices	plot-memcached-556dbfdc46-8c54k
# 10.244.0.9	media-microservices	plot-mongodb-7757d885b8-p8sf8
# 10.244.0.11	media-microservices	plot-service-6698596fd4-v24lr
# 10.244.0.6	media-microservices	rating-redis-75c5f5fd49-shtvz
# 10.244.0.24	media-microservices	rating-service-7bf447b7f4-t7dtj
# 10.244.0.25	media-microservices	review-storage-memcached-7b66898b76-r5xr2
# 10.244.0.31	media-microservices	review-storage-mongodb-f698997c7-bl7cl
# 10.244.0.21	media-microservices	review-storage-service-bb48dc4d8-l5wqc
# 10.244.0.30	media-microservices	text-service-6949778f76-jwsh9
# 10.244.0.17	media-microservices	unique-id-service-796d5876cc-mkzf8
# 10.244.0.28	media-microservices	user-memcached-574845dfc8-cj5xg
# 10.244.0.29	media-microservices	user-mongodb-6964d5bb96-9nrsv
# 10.244.0.15	media-microservices	user-review-mongodb-85ccc4bd6f-nx6pm
# 10.244.0.26	media-microservices	user-review-redis-558f76b88b-njhbf
# 10.244.0.33	media-microservices	user-review-service-66659b79cd-vhxwz
# 10.244.0.27	media-microservices	user-service-97d65b7cb-9srq6

# %%
api_client = client.ApiClient()
current_node = 0
node_names = ["minikube"]

# %%
api_client = client.ApiClient()
current_node = 0
node_names = ["minikube"]
response = api_client.call_api(f"/api/v1/nodes/{node_names[current_node]}/proxy/metrics/resource", "GET", response_type="str")
data = str(response[0])
rows = data.split("\n")
rows
# Out:
# ['# HELP container_cpu_usage_seconds_total [ALPHA] Cumulative cpu time consumed by the container in core-seconds',
#  '# TYPE container_cpu_usage_seconds_total counter',
#  'container_cpu_usage_seconds_total{container="cast-info-memcached",namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"} 1.863737 1709119445656',
#  'container_cpu_usage_seconds_total{container="cast-info-mongodb",namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"} 67.178791 1709119445662',
#  'container_cpu_usage_seconds_total{container="cast-info-service",namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"} 2.303045 1709119446795',
#  'container_cpu_usage_seconds_total{container="compose-review-memcached",namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"} 69.726172 1709119445446',
#  'container_cpu_usage_seconds_total{container="compose-review-service",namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"} 311.354159 1709119446675',
#  'container_cpu_usage_seconds_total{container="coredns",namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"} 22.318655 1709119445257',
#  'container_cpu_usage_seconds_total{container="etcd",namespace="kube-system",pod="etcd-minikube"} 212.605829 1709119445294',
#  'container_cpu_usage_seconds_total{container="jaeger",namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"} 5.504502 1709119445160',
#  'container_cpu_usage_seconds_total{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"} 545.506491 1709119445274',
#  'container_cpu_usage_seconds_total{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"} 166.890547 1709119445458',
#  'container_cpu_usage_seconds_total{container="kube-proxy",namespace="kube-system",pod="kube-proxy-ht6xb"} 5.253829 1709119445394',
#  'container_cpu_usage_seconds_total{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"} 33.529098 1709119445384',
#  'container_cpu_usage_seconds_total{container="kube-state-metrics",namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"} 6.450919 1709119445371',
#  'container_cpu_usage_seconds_total{container="movie-id-memcached",namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"} 15.200365 1709119445510',
#  'container_cpu_usage_seconds_total{container="movie-id-mongodb",namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"} 65.375776 1709119445718',
#  'container_cpu_usage_seconds_total{container="movie-id-service",namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"} 143.267642 1709119446757',
#  'container_cpu_usage_seconds_total{container="movie-info-memcached",namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"} 1.869352 1709119445663',
#  'container_cpu_usage_seconds_total{container="movie-info-mongodb",namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"} 64.755947 1709119445673',
#  'container_cpu_usage_seconds_total{container="movie-info-service",namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"} 0.49642 1709119446713',
#  'container_cpu_usage_seconds_total{container="movie-review-mongodb",namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"} 190.114068 1709119445663',
#  'container_cpu_usage_seconds_total{container="movie-review-redis",namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"} 34.030269 1709119445567',
#  'container_cpu_usage_seconds_total{container="movie-review-service",namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"} 90.569391 1709119446767',
#  'container_cpu_usage_seconds_total{container="nginx-web-server",namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"} 164.359209 1709119446094',
#  'container_cpu_usage_seconds_total{container="page-service",namespace="media-microservices",pod="page-service-54b69789b-6zgfz"} 0.051373 1709119446688',
#  'container_cpu_usage_seconds_total{container="plot-memcached",namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"} 1.884198 1709119445653',
#  'container_cpu_usage_seconds_total{container="plot-mongodb",namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"} 65.045088 1709119445664',
#  'container_cpu_usage_seconds_total{container="plot-service",namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"} 0.450149 1709119446707',
#  'container_cpu_usage_seconds_total{container="rating-redis",namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"} 40.263121 1709119445509',
#  'container_cpu_usage_seconds_total{container="rating-service",namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"} 117.743538 1709119446762',
#  'container_cpu_usage_seconds_total{container="review-storage-memcached",namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"} 1.848227 1709119445635',
#  'container_cpu_usage_seconds_total{container="review-storage-mongodb",namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"} 103.28414 1709119445710',
#  'container_cpu_usage_seconds_total{container="review-storage-service",namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"} 39.464775 1709119446709',
#  'container_cpu_usage_seconds_total{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"} 26.039186 1709119445160',
#  'container_cpu_usage_seconds_total{container="text-service",namespace="media-microservices",pod="text-service-6949778f76-jwsh9"} 29.03914 1709119446661',
#  'container_cpu_usage_seconds_total{container="unique-id-service",namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"} 41.40195 1709119446795',
#  'container_cpu_usage_seconds_total{container="user-memcached",namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"} 9.478635 1709119445460',
#  'container_cpu_usage_seconds_total{container="user-mongodb",namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"} 65.616766 1709119445620',
#  'container_cpu_usage_seconds_total{container="user-review-mongodb",namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"} 187.168981 1709119445550',
#  'container_cpu_usage_seconds_total{container="user-review-redis",namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"} 34.153041 1709119445656',
#  'container_cpu_usage_seconds_total{container="user-review-service",namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"} 91.398774 1709119446696',
#  'container_cpu_usage_seconds_total{container="user-service",namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"} 49.744881 1709119446715',
#  '# HELP container_memory_working_set_bytes [ALPHA] Current working set of the container in bytes',
#  '# TYPE container_memory_working_set_bytes gauge',
#  'container_memory_working_set_bytes{container="cast-info-memcached",namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"} 1.347584e+06 1709119445656',
#  'container_memory_working_set_bytes{container="cast-info-mongodb",namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"} 8.5778432e+07 1709119445662',
#  'container_memory_working_set_bytes{container="cast-info-service",namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"} 1.8075648e+07 1709119446795',
#  'container_memory_working_set_bytes{container="compose-review-memcached",namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"} 1.540096e+07 1709119445446',
#  'container_memory_working_set_bytes{container="compose-review-service",namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"} 1.6297984e+07 1709119446675',
#  'container_memory_working_set_bytes{container="coredns",namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"} 4.13696e+07 1709119445257',
#  'container_memory_working_set_bytes{container="etcd",namespace="kube-system",pod="etcd-minikube"} 5.689344e+07 1709119445294',
#  'container_memory_working_set_bytes{container="jaeger",namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"} 1.05877504e+08 1709119445160',
#  'container_memory_working_set_bytes{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"} 2.63061504e+08 1709119445274',
#  'container_memory_working_set_bytes{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"} 6.803456e+07 1709119445458',
#  'container_memory_working_set_bytes{container="kube-proxy",namespace="kube-system",pod="kube-proxy-ht6xb"} 2.7869184e+07 1709119445394',
#  'container_memory_working_set_bytes{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"} 3.5770368e+07 1709119445384',
#  'container_memory_working_set_bytes{container="kube-state-metrics",namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"} 2.0983808e+07 1709119445371',
#  'container_memory_working_set_bytes{container="movie-id-memcached",namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"} 7.069696e+06 1709119445510',
#  'container_memory_working_set_bytes{container="movie-id-mongodb",namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"} 3.9108608e+07 1709119445718',
#  'container_memory_working_set_bytes{container="movie-id-service",namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"} 7.991296e+06 1709119446757',
#  'container_memory_working_set_bytes{container="movie-info-memcached",namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"} 1.150976e+06 1709119445663',
#  'container_memory_working_set_bytes{container="movie-info-mongodb",namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"} 2.4756224e+07 1709119445673',
#  'container_memory_working_set_bytes{container="movie-info-service",namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"} 8.163328e+06 1709119446713',
#  'container_memory_working_set_bytes{container="movie-review-mongodb",namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"} 1.40890112e+08 1709119445663',
#  'container_memory_working_set_bytes{container="movie-review-redis",namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"} 2.904064e+06 1709119445567',
#  'container_memory_working_set_bytes{container="movie-review-service",namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"} 1.2857344e+07 1709119446767',
#  'container_memory_working_set_bytes{container="nginx-web-server",namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"} 2.4629248e+07 1709119446094',
#  'container_memory_working_set_bytes{container="page-service",namespace="media-microservices",pod="page-service-54b69789b-6zgfz"} 839680 1709119446688',
#  'container_memory_working_set_bytes{container="plot-memcached",namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"} 1.134592e+06 1709119445653',
#  'container_memory_working_set_bytes{container="plot-mongodb",namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"} 2.5464832e+07 1709119445664',
#  'container_memory_working_set_bytes{container="plot-service",namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"} 6.475776e+06 1709119446707',
#  'container_memory_working_set_bytes{container="rating-redis",namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"} 6.7584e+06 1709119445509',
#  'container_memory_working_set_bytes{container="rating-service",namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"} 9.613312e+06 1709119446762',
#  'container_memory_working_set_bytes{container="review-storage-memcached",namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"} 1.159168e+06 1709119445635',
#  'container_memory_working_set_bytes{container="review-storage-mongodb",namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"} 2.0717568e+08 1709119445710',
#  'container_memory_working_set_bytes{container="review-storage-service",namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"} 4.820992e+06 1709119446709',
#  'container_memory_working_set_bytes{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"} 2.4977408e+07 1709119445160',
#  'container_memory_working_set_bytes{container="text-service",namespace="media-microservices",pod="text-service-6949778f76-jwsh9"} 4.308992e+06 1709119446661',
#  'container_memory_working_set_bytes{container="unique-id-service",namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"} 4.366336e+06 1709119446795',
#  'container_memory_working_set_bytes{container="user-memcached",namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"} 4.28032e+06 1709119445460',
#  'container_memory_working_set_bytes{container="user-mongodb",namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"} 1.7874944e+07 1709119445620',
#  'container_memory_working_set_bytes{container="user-review-mongodb",namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"} 1.42249984e+08 1709119445550',
#  'container_memory_working_set_bytes{container="user-review-redis",namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"} 3.44064e+06 1709119445656',
#  'container_memory_working_set_bytes{container="user-review-service",namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"} 1.241088e+07 1709119446696',
#  'container_memory_working_set_bytes{container="user-service",namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"} 6.209536e+06 1709119446715',
#  '# HELP container_start_time_seconds [ALPHA] Start time of the container since unix epoch in seconds',
#  '# TYPE container_start_time_seconds gauge',
#  'container_start_time_seconds{container="cast-info-memcached",namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"} 1.709099225e+09 1709099225000',
#  'container_start_time_seconds{container="cast-info-mongodb",namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"} 1.709099572e+09 1709099572000',
#  'container_start_time_seconds{container="cast-info-service",namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"} 1.709099471e+09 1709099471000',
#  'container_start_time_seconds{container="compose-review-memcached",namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"} 1.709099566e+09 1709099566000',
#  'container_start_time_seconds{container="compose-review-service",namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"} 1.709099385e+09 1709099385000',
#  'container_start_time_seconds{container="coredns",namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"} 1.709099055e+09 1709099055000',
#  'container_start_time_seconds{container="etcd",namespace="kube-system",pod="etcd-minikube"} 1.709099036e+09 1709099036000',
#  'container_start_time_seconds{container="jaeger",namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"} 1.709099439e+09 1709099439000',
#  'container_start_time_seconds{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"} 1.709099036e+09 1709099036000',
#  'container_start_time_seconds{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"} 1.709099036e+09 1709099036000',
#  'container_start_time_seconds{container="kube-proxy",namespace="kube-system",pod="kube-proxy-ht6xb"} 1.709099054e+09 1709099054000',
#  'container_start_time_seconds{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"} 1.709099036e+09 1709099036000',
#  'container_start_time_seconds{container="kube-state-metrics",namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"} 1.709105114e+09 1709105114000',
#  'container_start_time_seconds{container="movie-id-memcached",namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"} 1.709099525e+09 1709099525000',
#  'container_start_time_seconds{container="movie-id-mongodb",namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"} 1.709099451e+09 1709099451000',
#  'container_start_time_seconds{container="movie-id-service",namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"} 1.709099446e+09 1709099446000',
#  'container_start_time_seconds{container="movie-info-memcached",namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"} 1.709099539e+09 1709099539000',
#  'container_start_time_seconds{container="movie-info-mongodb",namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"} 1.709099497e+09 1709099497000',
#  'container_start_time_seconds{container="movie-info-service",namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"} 1.709099466e+09 1709099466000',
#  'container_start_time_seconds{container="movie-review-mongodb",namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"} 1.709099204e+09 1709099204000',
#  'container_start_time_seconds{container="movie-review-redis",namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"} 1.709099448e+09 1709099448000',
#  'container_start_time_seconds{container="movie-review-service",namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"} 1.709099457e+09 1709099457000',
#  'container_start_time_seconds{container="nginx-web-server",namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"} 1.70909969e+09 1709099690000',
#  'container_start_time_seconds{container="page-service",namespace="media-microservices",pod="page-service-54b69789b-6zgfz"} 1.709099575e+09 1709099575000',
#  'container_start_time_seconds{container="plot-memcached",namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"} 1.709099463e+09 1709099463000',
#  'container_start_time_seconds{container="plot-mongodb",namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"} 1.709099443e+09 1709099443000',
#  'container_start_time_seconds{container="plot-service",namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"} 1.709099454e+09 1709099454000',
#  'container_start_time_seconds{container="rating-redis",namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"} 1.709099418e+09 1709099418000',
#  'container_start_time_seconds{container="rating-service",namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"} 1.709099543e+09 1709099543000',
#  'container_start_time_seconds{container="review-storage-memcached",namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"} 1.709099546e+09 1709099546000',
#  'container_start_time_seconds{container="review-storage-mongodb",namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"} 1.709099564e+09 1709099564000',
#  'container_start_time_seconds{container="review-storage-service",namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"} 1.709099508e+09 1709099508000',
#  'container_start_time_seconds{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"} 1.709099055e+09 1709099055000',
#  'container_start_time_seconds{container="text-service",namespace="media-microservices",pod="text-service-6949778f76-jwsh9"} 1.709099561e+09 1709099561000',
#  'container_start_time_seconds{container="unique-id-service",namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"} 1.709099468e+09 1709099468000',
#  'container_start_time_seconds{container="user-memcached",namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"} 1.709099555e+09 1709099555000',
#  'container_start_time_seconds{container="user-mongodb",namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"} 1.709099558e+09 1709099558000',
#  'container_start_time_seconds{container="user-review-mongodb",namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"} 1.70909946e+09 1709099460000',
#  'container_start_time_seconds{container="user-review-redis",namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"} 1.709099549e+09 1709099549000',
#  'container_start_time_seconds{container="user-review-service",namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"} 1.709099569e+09 1709099569000',
#  'container_start_time_seconds{container="user-service",namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"} 1.709099552e+09 1709099552000',
#  '# HELP node_cpu_usage_seconds_total [ALPHA] Cumulative cpu time consumed by the node in core-seconds',
#  '# TYPE node_cpu_usage_seconds_total counter',
#  'node_cpu_usage_seconds_total 42205.399265 1709119435310',
#  '# HELP node_memory_working_set_bytes [ALPHA] Current working set of the node in bytes',
#  '# TYPE node_memory_working_set_bytes gauge',
#  'node_memory_working_set_bytes 3.753668608e+09 1709119435310',
#  '# HELP pod_cpu_usage_seconds_total [ALPHA] Cumulative cpu time consumed by the pod in core-seconds',
#  '# TYPE pod_cpu_usage_seconds_total counter',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"} 22.331737 1709119442598',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="etcd-minikube"} 212.514887 1709119433226',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-apiserver-minikube"} 545.454658 1709119441686',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-controller-manager-minikube"} 166.900228 1709119443667',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-proxy-ht6xb"} 5.260428 1709119435583',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-scheduler-minikube"} 33.535799 1709119437223',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"} 6.4729 1709119442189',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="storage-provisioner"} 26.049839 1709119438648',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"} 1.881703 1709119441018',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"} 67.177194 1709119438431',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"} 2.322124 1709119432234',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"} 69.741296 1709119438725',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"} 311.372331 1709119443407',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"} 5.52313 1709119444188',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"} 15.216402 1709119438556',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"} 65.391121 1709119443877',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"} 143.286731 1709119446268',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"} 1.885052 1709119441765',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"} 64.742006 1709119434417',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"} 0.51168 1709119441976',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"} 190.121581 1709119441193',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"} 34.042424 1709119441170',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"} 90.586644 1709119443677',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"} 172.227432 1709119446305',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="page-service-54b69789b-6zgfz"} 0.069255 1709119435606',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"} 1.897486 1709119432143',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"} 65.064115 1709119445273',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"} 0.469358 1709119431131',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"} 40.279082 1709119443084',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"} 117.761568 1709119435446',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"} 1.864729 1709119440861',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"} 103.274318 1709119437440',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"} 39.479885 1709119436682',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="text-service-6949778f76-jwsh9"} 29.056193 1709119442314',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"} 41.421847 1709119444576',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"} 9.49559 1709119438868',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"} 65.627733 1709119443038',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"} 187.157494 1709119436893',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"} 34.155963 1709119436633',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"} 91.419677 1709119444869',
#  'pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"} 49.760611 1709119443945',
#  '# HELP pod_memory_working_set_bytes [ALPHA] Current working set of the pod in bytes',
#  '# TYPE pod_memory_working_set_bytes gauge',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"} 3.5356672e+07 1709119442598',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="etcd-minikube"} 5.3366784e+07 1709119433226',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-apiserver-minikube"} 2.57605632e+08 1709119441686',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-controller-manager-minikube"} 6.5540096e+07 1709119443667',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-proxy-ht6xb"} 2.7144192e+07 1709119435583',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-scheduler-minikube"} 3.4332672e+07 1709119437223',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"} 2.0606976e+07 1709119442189',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="storage-provisioner"} 2.408448e+07 1709119438648',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"} 1.753088e+06 1709119441018',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"} 8.1690624e+07 1709119438431',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"} 1.5597568e+07 1709119432234',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"} 1.5773696e+07 1709119438725',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"} 1.6699392e+07 1709119443407',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"} 9.7968128e+07 1709119444188',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"} 7.471104e+06 1709119438556',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"} 3.8785024e+07 1709119443877',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"} 8.298496e+06 1709119446268',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"} 1.531904e+06 1709119441765',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"} 2.4915968e+07 1709119434417',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"} 8.54016e+06 1709119441976',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"} 1.4092288e+08 1709119441193',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"} 3.559424e+06 1709119441170',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"} 1.2427264e+07 1709119443677',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"} 3.2899072e+07 1709119446305',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="page-service-54b69789b-6zgfz"} 1.20832e+06 1709119435606',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"} 1.536e+06 1709119432143',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"} 2.5632768e+07 1709119445273',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"} 6.08256e+06 1709119431131',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"} 6.684672e+06 1709119443084',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"} 1.001472e+07 1709119435446',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"} 1.564672e+06 1709119440861',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"} 2.07343616e+08 1709119437440',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"} 5.214208e+06 1709119436682',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="text-service-6949778f76-jwsh9"} 4.698112e+06 1709119442314',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"} 4.755456e+06 1709119444576',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"} 4.681728e+06 1709119438868',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"} 1.6543744e+07 1709119443038',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"} 1.40689408e+08 1709119436893',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"} 3.842048e+06 1709119436633',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"} 1.2529664e+07 1709119444869',
#  'pod_memory_working_set_bytes{namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"} 6.20544e+06 1709119443945',
#  '# HELP scrape_error [ALPHA] 1 if there was an error while getting container metrics, 0 otherwise',
#  '# TYPE scrape_error gauge',
#  'scrape_error 0',
#  '']

# %%
class Pods:
    def __init__(self):
        self.data = {}

    def __str__(self):
        return str(data)
    
    def __repr__(self):
        return str(data)
    
    def add_cpu(self, name, namespace, timestamp, value):
        try:
            self.data[name]["cpu"] = value
            self.data[name]["cpu_timestamp"] = timestamp
        except KeyError:
            self.data[name] = {"namespace": namespace, "pod": name, "cpu": value, "cpu_timestamp": timestamp}

    def add_memory(self, name, namespace, timestamp, value):
        try:
            self.data[name]["memory"] = value
            self.data[name]["memory_timestamp"] = timestamp
        except KeyError:
            self.data[name] = {"namespace": namespace, "pod": name, "memory": value, "memory_timestamp": timestamp}

class Nodes:
    def __init__(self):
        self.data = {}

    def __str__(self):
        return str(data)
    
    def __repr__(self):
        return str(data)
    
    def add_cpu(self, name, timestamp, value):
        try:
            self.data[name]["cpu"] = value
            self.data[name]["cpu_timestamp"] = timestamp
        except KeyError:
            self.data[name] = {"cpu": value, "cpu_timestamp": timestamp}

    def add_memory(self, name, timestamp, value):
        try:
            self.data[name]["memory"] = value
            self.data[name]["memory_timestamp"] = timestamp
        except KeyError:
            self.data[name] = {"memory": value, "memory_timestamp": timestamp}

class Containers:
    def __init__(self):
        self.data = {}

    def __str__(self):
        return str(data)
    
    def __repr__(self):
        return str(data)
    
    def add_cpu(self, name, namespace, pod, timestamp, value):
        try:
            self.data[pod]["cpu"] = value
            self.data[pod]["cpu_timestamp"] = timestamp
        except KeyError:
            self.data[pod] = {"namespace": namespace, "pod": pod, "container": name, "cpu": value, "cpu_timestamp": timestamp}

    def add_memory(self, name, namespace, pod, timestamp, value):
        try:
            self.data[pod]["memory"] = value
            self.data[pod]["memory_timestamp"] = timestamp
        except KeyError:
            self.data[pod] = {"namespace": namespace, "pod": pod, "container": name, "memory": value, "memory_timestamp": timestamp}

# %%
data = str(response[0])
rows = data.split("\n")

# Remove comments and empty lines
rows = [row for row in rows if not row.startswith("#") and row.strip() != ""]

# Split lines from rows
rows = [row.split() for row in rows]


# Create a dictionary with the data
pods = {}
containers = {}
nodes = {}
error_count = 0

def process_pod_or_container(row: list[str]):
    raw_name = row[0]
    value = row[1]
    timestamp = row[2]
    raw_type = raw_name.split("{")[0]
    pod = raw_name.split("\"")[-2].split("\"")[-1]
    namespace = raw_name.split("\"")[-4].split("\"")[-1]
    container = raw_name.split("\"")[1].split("\"")[0]
    match raw_type:
        case "container_cpu_usage_seconds_total":
            try:
                containers[pod]["cpu"] = value
                containers[pod]["cpu_timestamp"] = timestamp
            except KeyError:
                containers[pod] = {"namespace": namespace, "container": container, "pod": pod, "cpu": value, "cpu_timestamp": timestamp}
        case "container_memory_usage_bytes":
            try:
                containers[pod]["memory"] = value
                containers[pod]["memory_timestamp"] = timestamp
            except KeyError:
                containers[pod] = {"namespace": namespace, "container": container, "pod": pod, "memory": value, "memory_timestamp": timestamp}
        case "pod_memory_working_set_bytes":
            try:
                pods[pod]["memory"] = value
                pods[pod]["memory_timestamp"] = timestamp
            except KeyError:
                pods[pod] = {"namespace": namespace, "pod": pod, "memory": value, "memory_timestamp": timestamp}
        case "pod_cpu_usage_seconds_total":
            try:
                pods[pod]["cpu"] = value
                pods[pod]["cpu_timestamp"] = timestamp
            except KeyError:
                pods[pod] = {"namespace": namespace, "pod": pod, "cpu": value, "cpu_timestamp": timestamp}


def process_node(row):
    raw_type = row[0]
    value = row[1]
    timestamp = row[2]
    match raw_type:
        case "node_memory_working_set_bytes":
            try:
                nodes[node_names[current_node]]["memory"] = value 
            except KeyError:
                nodes[node_names[current_node]] = {"memory": value, "timestamp": timestamp}
        case "node_cpu_usage_seconds_total":
            try:
                nodes[node_names[current_node]]["cpu"] = value 
            except KeyError:
                nodes[node_names[current_node]] = {"cpu": value, "timestamp": timestamp}



for row in rows:
    try:
        if row[0] == "scrape_error":
            error_count = row[1]
        elif row[0][:4] == "node":
            process_node(row)
        else:
            process_pod_or_container(row)
            
    except IndexError:
        print("Error:",row)

# %%
containers
# Out:
# {'cast-info-memcached-56b648cb4-274nc': {'namespace': 'media-microservices',
#   'container': 'cast-info-memcached',
#   'pod': 'cast-info-memcached-56b648cb4-274nc',
#   'cpu': '1.831069',
#   'cpu_timestamp': '1709119067945',
#   'memory_timestamp': '1709119059484'},
#  'cast-info-mongodb-566f5887c-vqzp6': {'namespace': 'media-microservices',
#   'container': 'cast-info-mongodb',
#   'pod': 'cast-info-mongodb-566f5887c-vqzp6',
#   'cpu': '65.995307',
#   'cpu_timestamp': '1709119068060',
#   'memory_timestamp': '1709119066777'},
#  'cast-info-service-7ccdbff8-zf45m': {'namespace': 'media-microservices',
#   'container': 'cast-info-service',
#   'pod': 'cast-info-service-7ccdbff8-zf45m',
#   'cpu': '2.297739',
#   'cpu_timestamp': '1709119069107',
#   'memory_timestamp': '1709119053932'},
#  'compose-review-memcached-598d9dc6cd-cq2dm': {'namespace': 'media-microservices',
#   'container': 'compose-review-memcached',
#   'pod': 'compose-review-memcached-598d9dc6cd-cq2dm',
#   'cpu': '69.678921',
#   'cpu_timestamp': '1709119068055',
#   'memory_timestamp': '1709119060966'},
#  'compose-review-service-76ccb99f59-dgdcn': {'namespace': 'media-microservices',
#   'container': 'compose-review-service',
#   'pod': 'compose-review-service-76ccb99f59-dgdcn',
#   'cpu': '311.353522',
#   'cpu_timestamp': '1709119069154',
#   'memory_timestamp': '1709119063330'},
#  'coredns-5dd5756b68-xpdq5': {'namespace': 'kube-system',
#   'container': 'coredns',
#   'pod': 'coredns-5dd5756b68-xpdq5',
#   'cpu': '21.916929',
#   'cpu_timestamp': '1709119067618',
#   'memory_timestamp': '1709119062803'},
#  'etcd-minikube': {'namespace': 'kube-system',
#   'container': 'etcd',
#   'pod': 'etcd-minikube',
#   'cpu': '209.011908',
#   'cpu_timestamp': '1709119067771',
#   'memory_timestamp': '1709119065940'},
#  'jaeger-58bb7ff659-vs6dh': {'namespace': 'media-microservices',
#   'container': 'jaeger',
#   'pod': 'jaeger-58bb7ff659-vs6dh',
#   'cpu': '5.328963',
#   'cpu_timestamp': '1709119067685',
#   'memory_timestamp': '1709119058055'},
#  'kube-apiserver-minikube': {'namespace': 'kube-system',
#   'container': 'kube-apiserver',
#   'pod': 'kube-apiserver-minikube',
#   'cpu': '536.372874',
#   'cpu_timestamp': '1709119067782',
#   'memory_timestamp': '1709119059321'},
#  'kube-controller-manager-minikube': {'namespace': 'kube-system',
#   'container': 'kube-controller-manager',
#   'pod': 'kube-controller-manager-minikube',
#   'cpu': '164.105459',
#   'cpu_timestamp': '1709119067836',
#   'memory_timestamp': '1709119064855'},
#  'kube-proxy-ht6xb': {'namespace': 'kube-system',
#   'container': 'kube-proxy',
#   'pod': 'kube-proxy-ht6xb',
#   'cpu': '5.166801',
#   'cpu_timestamp': '1709119067873',
#   'memory_timestamp': '1709119066914'},
#  'kube-scheduler-minikube': {'namespace': 'kube-system',
#   'container': 'kube-scheduler',
#   'pod': 'kube-scheduler-minikube',
#   'cpu': '32.927702',
#   'cpu_timestamp': '1709119067771',
#   'memory_timestamp': '1709119065876'},
#  'kube-state-metrics-69dd4877d5-fvwjq': {'namespace': 'kube-system',
#   'container': 'kube-state-metrics',
#   'pod': 'kube-state-metrics-69dd4877d5-fvwjq',
#   'cpu': '6.296223',
#   'cpu_timestamp': '1709119067821',
#   'memory_timestamp': '1709119060981'},
#  'movie-id-memcached-d5c78ff8d-qv8sz': {'namespace': 'media-microservices',
#   'container': 'movie-id-memcached',
#   'pod': 'movie-id-memcached-d5c78ff8d-qv8sz',
#   'cpu': '15.148939',
#   'cpu_timestamp': '1709119068077',
#   'memory_timestamp': '1709119068281'},
#  'movie-id-mongodb-75479f887f-ktrb5': {'namespace': 'media-microservices',
#   'container': 'movie-id-mongodb',
#   'pod': 'movie-id-mongodb-75479f887f-ktrb5',
#   'cpu': '64.195311',
#   'cpu_timestamp': '1709119068124',
#   'memory_timestamp': '1709119063496'},
#  'movie-id-service-7d8d47875b-bdz9c': {'namespace': 'media-microservices',
#   'container': 'movie-id-service',
#   'pod': 'movie-id-service-7d8d47875b-bdz9c',
#   'cpu': '143.26239',
#   'cpu_timestamp': '1709119069156',
#   'memory_timestamp': '1709119061348'},
#  'movie-info-memcached-6d87c6f986-x25jz': {'namespace': 'media-microservices',
#   'container': 'movie-info-memcached',
#   'pod': 'movie-info-memcached-6d87c6f986-x25jz',
#   'cpu': '1.836219',
#   'cpu_timestamp': '1709119068036',
#   'memory_timestamp': '1709119065142'},
#  'movie-info-mongodb-7667c59cb8-tmhrf': {'namespace': 'media-microservices',
#   'container': 'movie-info-mongodb',
#   'pod': 'movie-info-mongodb-7667c59cb8-tmhrf',
#   'cpu': '63.573635',
#   'cpu_timestamp': '1709119068096',
#   'memory_timestamp': '1709119067660'},
#  'movie-info-service-558585d447-55dfn': {'namespace': 'media-microservices',
#   'container': 'movie-info-service',
#   'pod': 'movie-info-service-558585d447-55dfn',
#   'cpu': '0.490909',
#   'cpu_timestamp': '1709119068996',
#   'memory_timestamp': '1709119068048'},
#  'movie-review-mongodb-7d4cdd95d8-bw2fx': {'namespace': 'media-microservices',
#   'container': 'movie-review-mongodb',
#   'pod': 'movie-review-mongodb-7d4cdd95d8-bw2fx',
#   'cpu': '188.912813',
#   'cpu_timestamp': '1709119068174',
#   'memory_timestamp': '1709119065672'},
#  'movie-review-redis-6d9595df9f-7bb7z': {'namespace': 'media-microservices',
#   'container': 'movie-review-redis',
#   'pod': 'movie-review-redis-6d9595df9f-7bb7z',
#   'cpu': '33.410939',
#   'cpu_timestamp': '1709119068035',
#   'memory_timestamp': '1709119052997'},
#  'movie-review-service-5cd6f6586c-v67md': {'namespace': 'media-microservices',
#   'container': 'movie-review-service',
#   'pod': 'movie-review-service-5cd6f6586c-v67md',
#   'cpu': '90.564122',
#   'cpu_timestamp': '1709119069138',
#   'memory_timestamp': '1709119057428'},
#  'nginx-web-server-5f7b5f45c4-nbpkz': {'namespace': 'media-microservices',
#   'container': 'nginx-web-server',
#   'pod': 'nginx-web-server-5f7b5f45c4-nbpkz',
#   'cpu': '164.348844',
#   'cpu_timestamp': '1709119068541',
#   'memory_timestamp': '1709119063379'},
#  'page-service-54b69789b-6zgfz': {'namespace': 'media-microservices',
#   'container': 'page-service',
#   'pod': 'page-service-54b69789b-6zgfz',
#   'cpu': '0.050671',
#   'cpu_timestamp': '1709119069085',
#   'memory_timestamp': '1709119065487'},
#  'plot-memcached-556dbfdc46-8c54k': {'namespace': 'media-microservices',
#   'container': 'plot-memcached',
#   'pod': 'plot-memcached-556dbfdc46-8c54k',
#   'cpu': '1.849881',
#   'cpu_timestamp': '1709119068078',
#   'memory_timestamp': '1709119068289'},
#  'plot-mongodb-7757d885b8-p8sf8': {'namespace': 'media-microservices',
#   'container': 'plot-mongodb',
#   'pod': 'plot-mongodb-7757d885b8-p8sf8',
#   'cpu': '63.865193',
#   'cpu_timestamp': '1709119068135',
#   'memory_timestamp': '1709119061912'},
#  'plot-service-6698596fd4-v24lr': {'namespace': 'media-microservices',
#   'container': 'plot-service',
#   'pod': 'plot-service-6698596fd4-v24lr',
#   'cpu': '0.44504',
#   'cpu_timestamp': '1709119069121',
#   'memory_timestamp': '1709119056411'},
#  'rating-redis-75c5f5fd49-shtvz': {'namespace': 'media-microservices',
#   'container': 'rating-redis',
#   'pod': 'rating-redis-75c5f5fd49-shtvz',
#   'cpu': '39.655107',
#   'cpu_timestamp': '1709119067985',
#   'memory_timestamp': '1709119059630'},
#  'rating-service-7bf447b7f4-t7dtj': {'namespace': 'media-microservices',
#   'container': 'rating-service',
#   'pod': 'rating-service-7bf447b7f4-t7dtj',
#   'cpu': '117.742793',
#   'cpu_timestamp': '1709119069164',
#   'memory_timestamp': '1709119057193'},
#  'review-storage-memcached-7b66898b76-r5xr2': {'namespace': 'media-microservices',
#   'container': 'review-storage-memcached',
#   'pod': 'review-storage-memcached-7b66898b76-r5xr2',
#   'cpu': '1.814535',
#   'cpu_timestamp': '1709119068062',
#   'memory_timestamp': '1709119058344'},
#  'review-storage-mongodb-f698997c7-bl7cl': {'namespace': 'media-microservices',
#   'container': 'review-storage-mongodb',
#   'pod': 'review-storage-mongodb-f698997c7-bl7cl',
#   'cpu': '102.097599',
#   'cpu_timestamp': '1709119068094',
#   'memory_timestamp': '1709119056033'},
#  'review-storage-service-bb48dc4d8-l5wqc': {'namespace': 'media-microservices',
#   'container': 'review-storage-service',
#   'pod': 'review-storage-service-bb48dc4d8-l5wqc',
#   'cpu': '39.459892',
#   'cpu_timestamp': '1709119069165',
#   'memory_timestamp': '1709119059874'},
#  'storage-provisioner': {'namespace': 'kube-system',
#   'container': 'storage-provisioner',
#   'pod': 'storage-provisioner',
#   'cpu': '25.558249',
#   'cpu_timestamp': '1709119067676',
#   'memory_timestamp': '1709119063768'},
#  'text-service-6949778f76-jwsh9': {'namespace': 'media-microservices',
#   'container': 'text-service',
#   'pod': 'text-service-6949778f76-jwsh9',
#   'cpu': '29.038444',
#   'cpu_timestamp': '1709119069121',
#   'memory_timestamp': '1709119056960'},
#  'unique-id-service-796d5876cc-mkzf8': {'namespace': 'media-microservices',
#   'container': 'unique-id-service',
#   'pod': 'unique-id-service-796d5876cc-mkzf8',
#   'cpu': '41.401181',
#   'cpu_timestamp': '1709119069135',
#   'memory_timestamp': '1709119052901'},
#  'user-memcached-574845dfc8-cj5xg': {'namespace': 'media-microservices',
#   'container': 'user-memcached',
#   'pod': 'user-memcached-574845dfc8-cj5xg',
#   'cpu': '9.431595',
#   'cpu_timestamp': '1709119067983',
#   'memory_timestamp': '1709119063406'},
#  'user-mongodb-6964d5bb96-9nrsv': {'namespace': 'media-microservices',
#   'container': 'user-mongodb',
#   'pod': 'user-mongodb-6964d5bb96-9nrsv',
#   'cpu': '64.438142',
#   'cpu_timestamp': '1709119068124',
#   'memory_timestamp': '1709119066355'},
#  'user-review-mongodb-85ccc4bd6f-nx6pm': {'namespace': 'media-microservices',
#   'container': 'user-review-mongodb',
#   'pod': 'user-review-mongodb-85ccc4bd6f-nx6pm',
#   'cpu': '185.954124',
#   'cpu_timestamp': '1709119068122',
#   'memory_timestamp': '1709119065478'},
#  'user-review-redis-558f76b88b-njhbf': {'namespace': 'media-microservices',
#   'container': 'user-review-redis',
#   'pod': 'user-review-redis-558f76b88b-njhbf',
#   'cpu': '33.558895',
#   'cpu_timestamp': '1709119068001',
#   'memory_timestamp': '1709119061070'},
#  'user-review-service-66659b79cd-vhxwz': {'namespace': 'media-microservices',
#   'container': 'user-review-service',
#   'pod': 'user-review-service-66659b79cd-vhxwz',
#   'cpu': '91.393472',
#   'cpu_timestamp': '1709119069115',
#   'memory_timestamp': '1709119067988'},
#  'user-service-97d65b7cb-9srq6': {'namespace': 'media-microservices',
#   'container': 'user-service',
#   'pod': 'user-service-97d65b7cb-9srq6',
#   'cpu': '49.73933',
#   'cpu_timestamp': '1709119069134',
#   'memory_timestamp': '1709119068823'}}

# %%
pods
# Out:
# {'coredns-5dd5756b68-xpdq5': {'cpu': '11.362751',
#   'namespace': 'kube-system',
#   'timestamp': '1709109823228',
#   'pod': 'coredns-5dd5756b68-xpdq5',
#   'memory': '3.0539776e+07'},
#  'etcd-minikube': {'cpu': '112.087974',
#   'namespace': 'kube-system',
#   'timestamp': '1709109815866',
#   'pod': 'etcd-minikube',
#   'memory': '8.2300928e+07'},
#  'kube-apiserver-minikube': {'cpu': '288.816945',
#   'namespace': 'kube-system',
#   'timestamp': '1709109824472',
#   'pod': 'kube-apiserver-minikube',
#   'memory': '2.83435008e+08'},
#  'kube-controller-manager-minikube': {'cpu': '85.602686',
#   'namespace': 'kube-system',
#   'timestamp': '1709109816513',
#   'pod': 'kube-controller-manager-minikube',
#   'memory': '6.4032768e+07'},
#  'kube-proxy-ht6xb': {'cpu': '2.988617',
#   'namespace': 'kube-system',
#   'timestamp': '1709109825232',
#   'pod': 'kube-proxy-ht6xb',
#   'memory': '3.4811904e+07'},
#  'kube-scheduler-minikube': {'cpu': '17.420849',
#   'namespace': 'kube-system',
#   'timestamp': '1709109815429',
#   'pod': 'kube-scheduler-minikube',
#   'memory': '3.274752e+07'},
#  'kube-state-metrics-69dd4877d5-fvwjq': {'cpu': '2.155652',
#   'namespace': 'kube-system',
#   'timestamp': '1709109825144',
#   'pod': 'kube-state-metrics-69dd4877d5-fvwjq',
#   'memory': '1.9570688e+07'},
#  'storage-provisioner': {'cpu': '12.864822',
#   'namespace': 'kube-system',
#   'timestamp': '1709109821583',
#   'pod': 'storage-provisioner',
#   'memory': '2.3846912e+07'},
#  'cast-info-memcached-56b648cb4-274nc': {'cpu': '0.980752',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109817292',
#   'pod': 'cast-info-memcached-56b648cb4-274nc',
#   'memory': '3.956736e+06'},
#  'cast-info-mongodb-566f5887c-vqzp6': {'cpu': '33.219555',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811502',
#   'pod': 'cast-info-mongodb-566f5887c-vqzp6',
#   'memory': '2.8041216e+07'},
#  'cast-info-service-7ccdbff8-zf45m': {'cpu': '0.236436',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109820958',
#   'pod': 'cast-info-service-7ccdbff8-zf45m',
#   'memory': '2.674688e+06'},
#  'compose-review-memcached-598d9dc6cd-cq2dm': {'cpu': '0.957332',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109818734',
#   'pod': 'compose-review-memcached-598d9dc6cd-cq2dm',
#   'memory': '2.101248e+06'},
#  'compose-review-service-76ccb99f59-dgdcn': {'cpu': '0.052855',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109826056',
#   'pod': 'compose-review-service-76ccb99f59-dgdcn',
#   'memory': '2.281472e+06'},
#  'jaeger-58bb7ff659-vs6dh': {'cpu': '1.621107',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109812811',
#   'pod': 'jaeger-58bb7ff659-vs6dh',
#   'memory': '2.148352e+07'},
#  'movie-id-memcached-d5c78ff8d-qv8sz': {'cpu': '0.964412',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109814627',
#   'pod': 'movie-id-memcached-d5c78ff8d-qv8sz',
#   'memory': '2.121728e+06'},
#  'movie-id-mongodb-75479f887f-ktrb5': {'cpu': '32.938998',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109823332',
#   'pod': 'movie-id-mongodb-75479f887f-ktrb5',
#   'memory': '3.088384e+07'},
#  'movie-id-service-7d8d47875b-bdz9c': {'cpu': '0.19979',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109810184',
#   'pod': 'movie-id-service-7d8d47875b-bdz9c',
#   'memory': '2.125824e+06'},
#  'movie-info-memcached-6d87c6f986-x25jz': {'cpu': '0.97262',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109815821',
#   'pod': 'movie-info-memcached-6d87c6f986-x25jz',
#   'memory': '3.698688e+06'},
#  'movie-info-mongodb-7667c59cb8-tmhrf': {'cpu': '33.022398',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109822415',
#   'pod': 'movie-info-mongodb-7667c59cb8-tmhrf',
#   'memory': '2.015232e+07'},
#  'movie-info-service-558585d447-55dfn': {'cpu': '0.206244',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109825317',
#   'pod': 'movie-info-service-558585d447-55dfn',
#   'memory': '2.678784e+06'},
#  'movie-review-mongodb-7d4cdd95d8-bw2fx': {'cpu': '34.060742',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811539',
#   'pod': 'movie-review-mongodb-7d4cdd95d8-bw2fx',
#   'memory': '1.974272e+07'},
#  'movie-review-redis-6d9595df9f-7bb7z': {'cpu': '10.938089',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109824364',
#   'pod': 'movie-review-redis-6d9595df9f-7bb7z',
#   'memory': '2.113536e+06'},
#  'movie-review-service-5cd6f6586c-v67md': {'cpu': '0.181612',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109814735',
#   'pod': 'movie-review-service-5cd6f6586c-v67md',
#   'memory': '1.67936e+06'},
#  'nginx-web-server-5f7b5f45c4-nbpkz': {'cpu': '8.161377',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109815477',
#   'pod': 'nginx-web-server-5f7b5f45c4-nbpkz',
#   'memory': '2.7267072e+07'},
#  'page-service-54b69789b-6zgfz': {'cpu': '0.050344',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811853',
#   'pod': 'page-service-54b69789b-6zgfz',
#   'memory': '1.400832e+06'},
#  'plot-memcached-556dbfdc46-8c54k': {'cpu': '0.986347',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109826104',
#   'pod': 'plot-memcached-556dbfdc46-8c54k',
#   'memory': '1.691648e+06'},
#  'plot-mongodb-7757d885b8-p8sf8': {'cpu': '33.161806',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109818553',
#   'pod': 'plot-mongodb-7757d885b8-p8sf8',
#   'memory': '2.2298624e+07'},
#  'plot-service-6698596fd4-v24lr': {'cpu': '0.185386',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109813357',
#   'pod': 'plot-service-6698596fd4-v24lr',
#   'memory': '1.908736e+06'},
#  'rating-redis-75c5f5fd49-shtvz': {'cpu': '10.911292',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109825981',
#   'pod': 'rating-redis-75c5f5fd49-shtvz',
#   'memory': '3.29728e+06'},
#  'rating-service-7bf447b7f4-t7dtj': {'cpu': '0.055129',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109816303',
#   'pod': 'rating-service-7bf447b7f4-t7dtj',
#   'memory': '1.220608e+06'},
#  'review-storage-memcached-7b66898b76-r5xr2': {'cpu': '0.969875',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821926',
#   'pod': 'review-storage-memcached-7b66898b76-r5xr2',
#   'memory': '1.921024e+06'},
#  'review-storage-mongodb-f698997c7-bl7cl': {'cpu': '32.54372',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821812',
#   'pod': 'review-storage-mongodb-f698997c7-bl7cl',
#   'memory': '2.297856e+07'},
#  'review-storage-service-bb48dc4d8-l5wqc': {'cpu': '0.05058',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109819146',
#   'pod': 'review-storage-service-bb48dc4d8-l5wqc',
#   'memory': '2.367488e+06'},
#  'text-service-6949778f76-jwsh9': {'cpu': '0.053976',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109815065',
#   'pod': 'text-service-6949778f76-jwsh9',
#   'memory': '1.425408e+06'},
#  'unique-id-service-796d5876cc-mkzf8': {'cpu': '0.051883',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109823896',
#   'pod': 'unique-id-service-796d5876cc-mkzf8',
#   'memory': '1.101824e+06'},
#  'user-memcached-574845dfc8-cj5xg': {'cpu': '0.98147',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821943',
#   'pod': 'user-memcached-574845dfc8-cj5xg',
#   'memory': '1.695744e+06'},
#  'user-mongodb-6964d5bb96-9nrsv': {'cpu': '32.857544',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821506',
#   'pod': 'user-mongodb-6964d5bb96-9nrsv',
#   'memory': '2.2765568e+07'},
#  'user-review-mongodb-85ccc4bd6f-nx6pm': {'cpu': '33.335271',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109825939',
#   'pod': 'user-review-mongodb-85ccc4bd6f-nx6pm',
#   'memory': '2.19136e+07'},
#  'user-review-redis-558f76b88b-njhbf': {'cpu': '10.749',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109816533',
#   'pod': 'user-review-redis-558f76b88b-njhbf',
#   'memory': '2.629632e+06'},
#  'user-review-service-66659b79cd-vhxwz': {'cpu': '0.186488',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109808052',
#   'pod': 'user-review-service-66659b79cd-vhxwz',
#   'memory': '1.380352e+06'},
#  'user-service-97d65b7cb-9srq6': {'cpu': '0.050264',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811483',
#   'pod': 'user-service-97d65b7cb-9srq6',
#   'memory': '1.548288e+06'}}

# %%
import pandas as pd


df = pd.DataFrame(pods.values())
# Out:
# 41
# 41

# %%
# Delete the csv files
import os
os.remove("pods.csv")
os.remove("error_count.csv")
os.remove("containers.csv")
os.remove("nodes.csv")

# %%
import sched, time, os
import pandas as pd

# Create empty csv files

def do_something(scheduler): 
    # schedule the next call first
    scheduler.enter(5, 1, do_something, (scheduler,))
    print("Doing stuff...")

    # Create a dictionary with the data
    pods = {}
    containers = {}
    nodes = {}
    error_count = 0
    response = api_client.call_api(f"/api/v1/nodes/{node_names[current_node]}/proxy/metrics/resource", "GET", response_type="str")
    data = str(response[0])
    rows = data.split("\n")

    # Remove comments and empty lines
    rows = [row for row in rows if not row.startswith("#") and row.strip() != ""]

    # Split lines from rows
    rows = [row.split() for row in rows]

    for row in rows:
        try:
            if row[0] == "scrape_error":
                error_count = row[1]
            elif row[0][:4] == "node":
                process_node(row)
            else:
                process_pod_or_container(row)
                
        except IndexError:
            print("Error:",row)

    pods_df = pd.DataFrame(pods.values())
    pods_df.to_csv("pods.csv", mode='a', header=not os.path.exists("pods.csv"), index=False)

    containers_df = pd.DataFrame(containers.values())
    containers_df.to_csv("containers.csv", mode='a', header=not os.path.exists("containers.csv"), index=False)

    nodes_df = pd.DataFrame(nodes.values())
    nodes_df.to_csv("nodes.csv", mode='a', header=not os.path.exists("nodes.csv"), index=False)

    error_count_df = pd.DataFrame({"error_count": [error_count], "timestamp": [time.time()]})
    error_count_df.to_csv("error_count.csv", mode='a', header=not os.path.exists("error_count.csv"), index=False)

    print("Done")

my_scheduler = sched.scheduler(time.time, time.sleep)
my_scheduler.enter(0, 1, do_something, (my_scheduler,))
my_scheduler.run()
# Out:
# Doing stuff...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 55
#      53 my_scheduler = sched.scheduler(time.time, time.sleep)
#      54 my_scheduler.enter(0, 1, do_something, (my_scheduler,))
# ---> 55 my_scheduler.run()
#
# File /usr/lib/python3.11/sched.py:151, in scheduler.run(self, blocking)
#     149     delayfunc(time - now)
#     150 else:
# --> 151     action(*argument, **kwargs)
#     152     delayfunc(0)
#
# Cell In[15], line 38, in do_something(scheduler)
#      35     except IndexError:
#      36         print("Error:",row)
# ---> 38 print(pods_df)
#      39 pods_df = pd.DataFrame(pods.values())
#      40 pods_df.to_csv("pods.csv", mode='a', header=not os.path.exists("pods.csv"), index=False)
#
# UnboundLocalError: cannot access local variable 'pods_df' where it is not associated with a value
