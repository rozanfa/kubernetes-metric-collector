# %%
from kubernetes import client, config

# Configs can be set in Configuration class directly or using helper utility
config.load_kube_config()

v1 = client.CoreV1Api()
print("Listing pods with their IPs:")
ret = v1.list_namespaced_pod("social-network")
for i in ret.items:
    print("%s\t%s\t%s" % (i.status.pod_ip, i.metadata.namespace, i.metadata.name))
# Out:
# Listing pods with their IPs:
# 10.244.0.221	social-network	compose-post-service-866f6d7b74-hl962
# 10.244.0.232	social-network	home-timeline-redis-7994f7cb85-d89c9
# 10.244.0.211	social-network	home-timeline-service-bbc9bdd7b-cndcg
# 10.244.0.213	social-network	jaeger-7455bdbc47-jchjt
# 10.244.0.230	social-network	media-frontend-7f4999dcd-n64xn
# 10.244.0.217	social-network	media-memcached-7c887f8cc6-l5q56
# 10.244.0.231	social-network	media-mongodb-cb6857b9f-gwf5w
# 10.244.0.216	social-network	media-service-7848df64c4-74h8s
# 10.244.0.223	social-network	nginx-thrift-57fdb4c4f9-qn6tv
# 10.244.0.208	social-network	post-storage-memcached-675b5c57bd-smb49
# 10.244.0.224	social-network	post-storage-mongodb-5d7bfcd455-t6sdz
# 10.244.0.207	social-network	post-storage-service-84b659876c-7tt26
# 10.244.0.212	social-network	social-graph-mongodb-78b95799d7-856w7
# 10.244.0.215	social-network	social-graph-redis-7d9b494f66-px74j
# 10.244.0.226	social-network	social-graph-service-55b7888dc7-b6jzj
# 10.244.0.227	social-network	text-service-76cf6557f7-zxtdn
# 10.244.0.222	social-network	unique-id-service-6b88dd4658-fzx7l
# 10.244.0.220	social-network	url-shorten-memcached-55d47ccc88-7qv4c
# 10.244.0.214	social-network	url-shorten-mongodb-5697666656-cj7vm
# 10.244.0.229	social-network	url-shorten-service-6d8bbf75f8-dgrh6
# 10.244.0.219	social-network	user-memcached-67b7d46c5b-gsgk4
# 10.244.0.225	social-network	user-mention-service-764c7d97c5-7rw64
# 10.244.0.235	social-network	user-mongodb-86bb4559d-nmlch
# 10.244.0.210	social-network	user-service-74685b9465-8qlhb
# 10.244.0.228	social-network	user-timeline-mongodb-687f6576fb-m94rm
# 10.244.0.218	social-network	user-timeline-redis-6bf758cc4f-5mndw
# 10.244.0.233	social-network	user-timeline-service-65d5766796-2wnnp

# %%
api_client = client.ApiClient()
current_node = 0
node_names = list(map(lambda x: x.metadata.name, v1.list_node().items))
node_names
# Out:
# ['minikube']

# %%
api_client = client.ApiClient()
current_node = 0
node_names = ["minikube"]
response = api_client.call_api(f"/api/v1/nodes/{node_names[current_node]}/proxy/metrics/resource", "GET", response_type="str")
data = str(response[0])
rows = data.split("\n")
rows
# Out:
# ['# HELP container_cpu_usage_seconds_total [ALPHA] Cumulative cpu time consumed by the container in core-seconds',
#  '# TYPE container_cpu_usage_seconds_total counter',
#  'container_cpu_usage_seconds_total{container="compose-post-service",namespace="social-network",pod="compose-post-service-866f6d7b74-hl962"} 338.52345 1712920684063',
#  'container_cpu_usage_seconds_total{container="controller",namespace="ingress-nginx",pod="ingress-nginx-controller-7799c6795f-s4mkb"} 192.415299 1712920683020',
#  'container_cpu_usage_seconds_total{container="coredns",namespace="kube-system",pod="coredns-5d78c9869d-lcldh"} 7.566781 1712920683690',
#  'container_cpu_usage_seconds_total{container="etcd",namespace="kube-system",pod="etcd-minikube"} 63.913114 1712920683789',
#  'container_cpu_usage_seconds_total{container="home-timeline-redis",namespace="social-network",pod="home-timeline-redis-7994f7cb85-d89c9"} 152.79111 1712920684044',
#  'container_cpu_usage_seconds_total{container="home-timeline-service",namespace="social-network",pod="home-timeline-service-bbc9bdd7b-cndcg"} 62.106974 1712920684169',
#  'container_cpu_usage_seconds_total{container="jaeger",namespace="social-network",pod="jaeger-7455bdbc47-jchjt"} 46.203976 1712920683928',
#  'container_cpu_usage_seconds_total{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"} 131.537513 1712920683802',
#  'container_cpu_usage_seconds_total{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"} 55.397913 1712920684045',
#  'container_cpu_usage_seconds_total{container="kube-proxy",namespace="kube-system",pod="kube-proxy-p8wcq"} 1.672111 1712920683984',
#  'container_cpu_usage_seconds_total{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"} 9.207513 1712920683861',
#  'container_cpu_usage_seconds_total{container="media-frontend",namespace="social-network",pod="media-frontend-7f4999dcd-n64xn"} 0.061269 1712920684574',
#  'container_cpu_usage_seconds_total{container="media-memcached",namespace="social-network",pod="media-memcached-7c887f8cc6-l5q56"} 0.556675 1712920684005',
#  'container_cpu_usage_seconds_total{container="media-mongodb",namespace="social-network",pod="media-mongodb-cb6857b9f-gwf5w"} 17.066165 1712920684131',
#  'container_cpu_usage_seconds_total{container="media-service",namespace="social-network",pod="media-service-7848df64c4-74h8s"} 23.264332 1712920684098',
#  'container_cpu_usage_seconds_total{container="metrics-server",namespace="kube-system",pod="metrics-server-7746886d4f-cnvs4"} 10.637611 1712920683883',
#  'container_cpu_usage_seconds_total{container="nginx-thrift",namespace="social-network",pod="nginx-thrift-57fdb4c4f9-qn6tv"} 178.615305 1712920684414',
#  'container_cpu_usage_seconds_total{container="post-storage-memcached",namespace="social-network",pod="post-storage-memcached-675b5c57bd-smb49"} 0.57131 1712920684055',
#  'container_cpu_usage_seconds_total{container="post-storage-mongodb",namespace="social-network",pod="post-storage-mongodb-5d7bfcd455-t6sdz"} 89.092198 1712920684082',
#  'container_cpu_usage_seconds_total{container="post-storage-service",namespace="social-network",pod="post-storage-service-84b659876c-7tt26"} 51.55697 1712920684105',
#  'container_cpu_usage_seconds_total{container="social-graph-mongodb",namespace="social-network",pod="social-graph-mongodb-78b95799d7-856w7"} 50.311419 1712920684107',
#  'container_cpu_usage_seconds_total{container="social-graph-redis",namespace="social-network",pod="social-graph-redis-7d9b494f66-px74j"} 22.134518 1712920684080',
#  'container_cpu_usage_seconds_total{container="social-graph-service",namespace="social-network",pod="social-graph-service-55b7888dc7-b6jzj"} 81.549663 1712920684080',
#  'container_cpu_usage_seconds_total{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"} 7.627386 1712920683681',
#  'container_cpu_usage_seconds_total{container="text-service",namespace="social-network",pod="text-service-76cf6557f7-zxtdn"} 176.937929 1712920684201',
#  'container_cpu_usage_seconds_total{container="unique-id-service",namespace="social-network",pod="unique-id-service-6b88dd4658-fzx7l"} 24.486269 1712920684124',
#  'container_cpu_usage_seconds_total{container="url-shorten-memcached",namespace="social-network",pod="url-shorten-memcached-55d47ccc88-7qv4c"} 0.554496 1712920683995',
#  'container_cpu_usage_seconds_total{container="url-shorten-mongodb",namespace="social-network",pod="url-shorten-mongodb-5697666656-cj7vm"} 123.388703 1712920684172',
#  'container_cpu_usage_seconds_total{container="url-shorten-service",namespace="social-network",pod="url-shorten-service-6d8bbf75f8-dgrh6"} 85.140501 1712920684069',
#  'container_cpu_usage_seconds_total{container="user-memcached",namespace="social-network",pod="user-memcached-67b7d46c5b-gsgk4"} 39.084292 1712920684006',
#  'container_cpu_usage_seconds_total{container="user-mention-service",namespace="social-network",pod="user-mention-service-764c7d97c5-7rw64"} 64.825606 1712920684095',
#  'container_cpu_usage_seconds_total{container="user-mongodb",namespace="social-network",pod="user-mongodb-86bb4559d-nmlch"} 34.339431 1712920684108',
#  'container_cpu_usage_seconds_total{container="user-service",namespace="social-network",pod="user-service-74685b9465-8qlhb"} 27.893279 1712920684178',
#  'container_cpu_usage_seconds_total{container="user-timeline-mongodb",namespace="social-network",pod="user-timeline-mongodb-687f6576fb-m94rm"} 165.39237 1712920684095',
#  'container_cpu_usage_seconds_total{container="user-timeline-redis",namespace="social-network",pod="user-timeline-redis-6bf758cc4f-5mndw"} 22.363643 1712920684122',
#  'container_cpu_usage_seconds_total{container="user-timeline-service",namespace="social-network",pod="user-timeline-service-65d5766796-2wnnp"} 60.944344 1712920684052',
#  '# HELP container_memory_working_set_bytes [ALPHA] Current working set of the container in bytes',
#  '# TYPE container_memory_working_set_bytes gauge',
#  'container_memory_working_set_bytes{container="compose-post-service",namespace="social-network",pod="compose-post-service-866f6d7b74-hl962"} 5.79584e+06 1712920684063',
#  'container_memory_working_set_bytes{container="controller",namespace="ingress-nginx",pod="ingress-nginx-controller-7799c6795f-s4mkb"} 1.3252608e+08 1712920683020',
#  'container_memory_working_set_bytes{container="coredns",namespace="kube-system",pod="coredns-5d78c9869d-lcldh"} 2.248704e+07 1712920683690',
#  'container_memory_working_set_bytes{container="etcd",namespace="kube-system",pod="etcd-minikube"} 6.6879488e+07 1712920683789',
#  'container_memory_working_set_bytes{container="home-timeline-redis",namespace="social-network",pod="home-timeline-redis-7994f7cb85-d89c9"} 1.14845696e+09 1712920684044',
#  'container_memory_working_set_bytes{container="home-timeline-service",namespace="social-network",pod="home-timeline-service-bbc9bdd7b-cndcg"} 6.557696e+06 1712920684169',
#  'container_memory_working_set_bytes{container="jaeger",namespace="social-network",pod="jaeger-7455bdbc47-jchjt"} 9.69633792e+08 1712920683928',
#  'container_memory_working_set_bytes{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"} 2.61361664e+08 1712920683802',
#  'container_memory_working_set_bytes{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"} 5.9072512e+07 1712920684045',
#  'container_memory_working_set_bytes{container="kube-proxy",namespace="kube-system",pod="kube-proxy-p8wcq"} 2.7574272e+07 1712920683984',
#  'container_memory_working_set_bytes{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"} 2.3814144e+07 1712920683861',
#  'container_memory_working_set_bytes{container="media-frontend",namespace="social-network",pod="media-frontend-7f4999dcd-n64xn"} 1.5839232e+07 1712920684574',
#  'container_memory_working_set_bytes{container="media-memcached",namespace="social-network",pod="media-memcached-7c887f8cc6-l5q56"} 1.14688e+06 1712920684005',
#  'container_memory_working_set_bytes{container="media-mongodb",namespace="social-network",pod="media-mongodb-cb6857b9f-gwf5w"} 3.8559744e+07 1712920684131',
#  'container_memory_working_set_bytes{container="media-service",namespace="social-network",pod="media-service-7848df64c4-74h8s"} 1.830912e+06 1712920684098',
#  'container_memory_working_set_bytes{container="metrics-server",namespace="kube-system",pod="metrics-server-7746886d4f-cnvs4"} 3.209216e+07 1712920683883',
#  'container_memory_working_set_bytes{container="nginx-thrift",namespace="social-network",pod="nginx-thrift-57fdb4c4f9-qn6tv"} 5.8638336e+07 1712920684414',
#  'container_memory_working_set_bytes{container="post-storage-memcached",namespace="social-network",pod="post-storage-memcached-675b5c57bd-smb49"} 1.138688e+06 1712920684055',
#  'container_memory_working_set_bytes{container="post-storage-mongodb",namespace="social-network",pod="post-storage-mongodb-5d7bfcd455-t6sdz"} 2.81198592e+08 1712920684082',
#  'container_memory_working_set_bytes{container="post-storage-service",namespace="social-network",pod="post-storage-service-84b659876c-7tt26"} 4.022272e+06 1712920684105',
#  'container_memory_working_set_bytes{container="social-graph-mongodb",namespace="social-network",pod="social-graph-mongodb-78b95799d7-856w7"} 1.4475264e+08 1712920684107',
#  'container_memory_working_set_bytes{container="social-graph-redis",namespace="social-network",pod="social-graph-redis-7d9b494f66-px74j"} 9.388032e+06 1712920684080',
#  'container_memory_working_set_bytes{container="social-graph-service",namespace="social-network",pod="social-graph-service-55b7888dc7-b6jzj"} 2.4649728e+07 1712920684080',
#  'container_memory_working_set_bytes{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"} 1.734656e+07 1712920683681',
#  'container_memory_working_set_bytes{container="text-service",namespace="social-network",pod="text-service-76cf6557f7-zxtdn"} 6.627328e+06 1712920684201',
#  'container_memory_working_set_bytes{container="unique-id-service",namespace="social-network",pod="unique-id-service-6b88dd4658-fzx7l"} 1.646592e+06 1712920684124',
#  'container_memory_working_set_bytes{container="url-shorten-memcached",namespace="social-network",pod="url-shorten-memcached-55d47ccc88-7qv4c"} 1.134592e+06 1712920683995',
#  'container_memory_working_set_bytes{container="url-shorten-mongodb",namespace="social-network",pod="url-shorten-mongodb-5697666656-cj7vm"} 2.96341504e+08 1712920684172',
#  'container_memory_working_set_bytes{container="url-shorten-service",namespace="social-network",pod="url-shorten-service-6d8bbf75f8-dgrh6"} 5.287936e+06 1712920684069',
#  'container_memory_working_set_bytes{container="user-memcached",namespace="social-network",pod="user-memcached-67b7d46c5b-gsgk4"} 4.251648e+06 1712920684006',
#  'container_memory_working_set_bytes{container="user-mention-service",namespace="social-network",pod="user-mention-service-764c7d97c5-7rw64"} 3.313664e+06 1712920684095',
#  'container_memory_working_set_bytes{container="user-mongodb",namespace="social-network",pod="user-mongodb-86bb4559d-nmlch"} 8.404992e+07 1712920684108',
#  'container_memory_working_set_bytes{container="user-service",namespace="social-network",pod="user-service-74685b9465-8qlhb"} 1.3340672e+07 1712920684178',
#  'container_memory_working_set_bytes{container="user-timeline-mongodb",namespace="social-network",pod="user-timeline-mongodb-687f6576fb-m94rm"} 1.62205696e+08 1712920684095',
#  'container_memory_working_set_bytes{container="user-timeline-redis",namespace="social-network",pod="user-timeline-redis-6bf758cc4f-5mndw"} 4.6125056e+07 1712920684122',
#  'container_memory_working_set_bytes{container="user-timeline-service",namespace="social-network",pod="user-timeline-service-65d5766796-2wnnp"} 5.984256e+06 1712920684052',
#  '# HELP container_start_time_seconds [ALPHA] Start time of the container since unix epoch in seconds',
#  '# TYPE container_start_time_seconds gauge',
#  'container_start_time_seconds{container="compose-post-service",namespace="social-network",pod="compose-post-service-866f6d7b74-hl962"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="controller",namespace="ingress-nginx",pod="ingress-nginx-controller-7799c6795f-s4mkb"} 1.712915455e+09 1712915455000',
#  'container_start_time_seconds{container="coredns",namespace="kube-system",pod="coredns-5d78c9869d-lcldh"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="etcd",namespace="kube-system",pod="etcd-minikube"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="home-timeline-redis",namespace="social-network",pod="home-timeline-redis-7994f7cb85-d89c9"} 1.712915455e+09 1712915455000',
#  'container_start_time_seconds{container="home-timeline-service",namespace="social-network",pod="home-timeline-service-bbc9bdd7b-cndcg"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="jaeger",namespace="social-network",pod="jaeger-7455bdbc47-jchjt"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"} 1.712915453e+09 1712915453000',
#  'container_start_time_seconds{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="kube-proxy",namespace="kube-system",pod="kube-proxy-p8wcq"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="media-frontend",namespace="social-network",pod="media-frontend-7f4999dcd-n64xn"} 1.712917017e+09 1712917017000',
#  'container_start_time_seconds{container="media-memcached",namespace="social-network",pod="media-memcached-7c887f8cc6-l5q56"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="media-mongodb",namespace="social-network",pod="media-mongodb-cb6857b9f-gwf5w"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="media-service",namespace="social-network",pod="media-service-7848df64c4-74h8s"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="metrics-server",namespace="kube-system",pod="metrics-server-7746886d4f-cnvs4"} 1.712915455e+09 1712915455000',
#  'container_start_time_seconds{container="nginx-thrift",namespace="social-network",pod="nginx-thrift-57fdb4c4f9-qn6tv"} 1.712916796e+09 1712916796000',
#  'container_start_time_seconds{container="post-storage-memcached",namespace="social-network",pod="post-storage-memcached-675b5c57bd-smb49"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="post-storage-mongodb",namespace="social-network",pod="post-storage-mongodb-5d7bfcd455-t6sdz"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="post-storage-service",namespace="social-network",pod="post-storage-service-84b659876c-7tt26"} 1.712915453e+09 1712915453000',
#  'container_start_time_seconds{container="social-graph-mongodb",namespace="social-network",pod="social-graph-mongodb-78b95799d7-856w7"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="social-graph-redis",namespace="social-network",pod="social-graph-redis-7d9b494f66-px74j"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="social-graph-service",namespace="social-network",pod="social-graph-service-55b7888dc7-b6jzj"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="text-service",namespace="social-network",pod="text-service-76cf6557f7-zxtdn"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="unique-id-service",namespace="social-network",pod="unique-id-service-6b88dd4658-fzx7l"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="url-shorten-memcached",namespace="social-network",pod="url-shorten-memcached-55d47ccc88-7qv4c"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="url-shorten-mongodb",namespace="social-network",pod="url-shorten-mongodb-5697666656-cj7vm"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="url-shorten-service",namespace="social-network",pod="url-shorten-service-6d8bbf75f8-dgrh6"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="user-memcached",namespace="social-network",pod="user-memcached-67b7d46c5b-gsgk4"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="user-mention-service",namespace="social-network",pod="user-mention-service-764c7d97c5-7rw64"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="user-mongodb",namespace="social-network",pod="user-mongodb-86bb4559d-nmlch"} 1.712915455e+09 1712915455000',
#  'container_start_time_seconds{container="user-service",namespace="social-network",pod="user-service-74685b9465-8qlhb"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="user-timeline-mongodb",namespace="social-network",pod="user-timeline-mongodb-687f6576fb-m94rm"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="user-timeline-redis",namespace="social-network",pod="user-timeline-redis-6bf758cc4f-5mndw"} 1.712915454e+09 1712915454000',
#  'container_start_time_seconds{container="user-timeline-service",namespace="social-network",pod="user-timeline-service-65d5766796-2wnnp"} 1.712915455e+09 1712915455000',
#  '# HELP node_cpu_usage_seconds_total [ALPHA] Cumulative cpu time consumed by the node in core-seconds',
#  '# TYPE node_cpu_usage_seconds_total counter',
#  'node_cpu_usage_seconds_total 17551.83634 1712920677237',
#  '# HELP node_memory_working_set_bytes [ALPHA] Current working set of the node in bytes',
#  '# TYPE node_memory_working_set_bytes gauge',
#  'node_memory_working_set_bytes 5.504401408e+09 1712920677237',
#  '# HELP pod_cpu_usage_seconds_total [ALPHA] Cumulative cpu time consumed by the pod in core-seconds',
#  '# TYPE pod_cpu_usage_seconds_total counter',
#  'pod_cpu_usage_seconds_total{namespace="ingress-nginx",pod="ingress-nginx-controller-7799c6795f-s4mkb"} 200.131064 1712920674912',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="coredns-5d78c9869d-lcldh"} 9.283523 1712920679201',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="etcd-minikube"} 81.823981 1712920679875',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-apiserver-minikube"} 168.200414 1712920671301',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-controller-manager-minikube"} 78.563746 1712920672533',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-proxy-p8wcq"} 2.437139 1712920678060',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-scheduler-minikube"} 12.200886 1712920681830',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="metrics-server-7746886d4f-cnvs4"} 13.628532 1712920683608',
#  'pod_cpu_usage_seconds_total{namespace="kube-system",pod="storage-provisioner"} 9.124171 1712920672872',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="compose-post-service-866f6d7b74-hl962"} 338.598888 1712920679239',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="home-timeline-redis-7994f7cb85-d89c9"} 154.594219 1712920669477',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="home-timeline-service-bbc9bdd7b-cndcg"} 62.18876 1712920670048',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="jaeger-7455bdbc47-jchjt"} 46.549638 1712920683565',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="media-frontend-7f4999dcd-n64xn"} 30.859839 1712920671081',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="media-memcached-7c887f8cc6-l5q56"} 0.767449 1712920671457',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="media-mongodb-cb6857b9f-gwf5w"} 22.019431 1712920668692',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="media-service-7848df64c4-74h8s"} 23.341583 1712920676275',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="nginx-thrift-57fdb4c4f9-qn6tv"} 203.816008 1712920675435',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="post-storage-memcached-675b5c57bd-smb49"} 0.783835 1712920676900',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="post-storage-mongodb-5d7bfcd455-t6sdz"} 94.138243 1712920678775',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="post-storage-service-84b659876c-7tt26"} 51.654799 1712920680567',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="social-graph-mongodb-78b95799d7-856w7"} 55.348383 1712920667925',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="social-graph-redis-7d9b494f66-px74j"} 24.045041 1712920681325',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="social-graph-service-55b7888dc7-b6jzj"} 81.657628 1712920678945',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="text-service-76cf6557f7-zxtdn"} 177.017634 1712920673938',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="unique-id-service-6b88dd4658-fzx7l"} 24.565066 1712920682595',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="url-shorten-memcached-55d47ccc88-7qv4c"} 0.773652 1712920676286',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="url-shorten-mongodb-5697666656-cj7vm"} 128.379778 1712920675197',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="url-shorten-service-6d8bbf75f8-dgrh6"} 85.240811 1712920683992',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-memcached-67b7d46c5b-gsgk4"} 39.302647 1712920682876',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-mention-service-764c7d97c5-7rw64"} 64.906346 1712920679939',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-mongodb-86bb4559d-nmlch"} 39.267706 1712920677235',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-service-74685b9465-8qlhb"} 27.992997 1712920672836',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-timeline-mongodb-687f6576fb-m94rm"} 170.457858 1712920679841',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-timeline-redis-6bf758cc4f-5mndw"} 24.171118 1712920674014',
#  'pod_cpu_usage_seconds_total{namespace="social-network",pod="user-timeline-service-65d5766796-2wnnp"} 61.053781 1712920683882',
#  '# HELP pod_memory_working_set_bytes [ALPHA] Current working set of the pod in bytes',
#  '# TYPE pod_memory_working_set_bytes gauge',
#  'pod_memory_working_set_bytes{namespace="ingress-nginx",pod="ingress-nginx-controller-7799c6795f-s4mkb"} 1.3359104e+08 1712920674912',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="coredns-5d78c9869d-lcldh"} 2.4485888e+07 1712920679201',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="etcd-minikube"} 6.846464e+07 1712920679875',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-apiserver-minikube"} 2.70299136e+08 1712920671301',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-controller-manager-minikube"} 6.3045632e+07 1712920672533',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-proxy-p8wcq"} 2.8721152e+07 1712920678060',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="kube-scheduler-minikube"} 2.6779648e+07 1712920681830',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="metrics-server-7746886d4f-cnvs4"} 3.5397632e+07 1712920683608',
#  'pod_memory_working_set_bytes{namespace="kube-system",pod="storage-provisioner"} 2.000896e+07 1712920672872',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="compose-post-service-866f6d7b74-hl962"} 6.201344e+06 1712920679239',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="home-timeline-redis-7994f7cb85-d89c9"} 1.149374464e+09 1712920669477',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="home-timeline-service-bbc9bdd7b-cndcg"} 7.221248e+06 1712920670048',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="jaeger-7455bdbc47-jchjt"} 9.69465856e+08 1712920683565',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="media-frontend-7f4999dcd-n64xn"} 2.4219648e+07 1712920671081',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="media-memcached-7c887f8cc6-l5q56"} 1.72032e+06 1712920671457',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="media-mongodb-cb6857b9f-gwf5w"} 3.989504e+07 1712920668692',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="media-service-7848df64c4-74h8s"} 2.23232e+06 1712920676275',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="nginx-thrift-57fdb4c4f9-qn6tv"} 6.4151552e+07 1712920675435',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="post-storage-memcached-675b5c57bd-smb49"} 1.527808e+06 1712920676900',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="post-storage-mongodb-5d7bfcd455-t6sdz"} 2.82513408e+08 1712920678775',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="post-storage-service-84b659876c-7tt26"} 4.657152e+06 1712920680567',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="social-graph-mongodb-78b95799d7-856w7"} 1.4600192e+08 1712920667925',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="social-graph-redis-7d9b494f66-px74j"} 9.674752e+06 1712920681325',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="social-graph-service-55b7888dc7-b6jzj"} 2.5337856e+07 1712920678945',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="text-service-76cf6557f7-zxtdn"} 7.233536e+06 1712920673938',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="unique-id-service-6b88dd4658-fzx7l"} 2.113536e+06 1712920682595',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="url-shorten-memcached-55d47ccc88-7qv4c"} 1.536e+06 1712920676286',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="url-shorten-mongodb-5697666656-cj7vm"} 2.98180608e+08 1712920675197',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="url-shorten-service-6d8bbf75f8-dgrh6"} 5.562368e+06 1712920683992',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-memcached-67b7d46c5b-gsgk4"} 4.857856e+06 1712920682876',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-mention-service-764c7d97c5-7rw64"} 3.743744e+06 1712920679939',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-mongodb-86bb4559d-nmlch"} 8.4791296e+07 1712920677235',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-service-74685b9465-8qlhb"} 1.3774848e+07 1712920672836',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-timeline-mongodb-687f6576fb-m94rm"} 1.63602432e+08 1712920679841',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-timeline-redis-6bf758cc4f-5mndw"} 4.6252032e+07 1712920674014',
#  'pod_memory_working_set_bytes{namespace="social-network",pod="user-timeline-service-65d5766796-2wnnp"} 7.76192e+06 1712920683882',
#  '# HELP scrape_error [ALPHA] 1 if there was an error while getting container metrics, 0 otherwise',
#  '# TYPE scrape_error gauge',
#  'scrape_error 0',
#  '']

# %%
# class Pods:
#     def __init__(self):
#         self.data = {}

#     def __str__(self):
#         return str(data)
    
#     def __repr__(self):
#         return str(data)
    
#     def add_cpu(self, name, namespace, timestamp, value):
#         try:
#             self.data[name]["cpu"] = value
#             self.data[name]["cpu_timestamp"] = timestamp
#         except KeyError:
#             self.data[name] = {"namespace": namespace, "pod": name, "cpu": value, "cpu_timestamp": timestamp}

#     def add_memory(self, name, namespace, timestamp, value):
#         try:
#             self.data[name]["memory"] = value
#             self.data[name]["memory_timestamp"] = timestamp
#         except KeyError:
#             self.data[name] = {"namespace": namespace, "pod": name, "memory": value, "memory_timestamp": timestamp}

# class Nodes:
#     def __init__(self):
#         self.data = {}

#     def __str__(self):
#         return str(data)
    
#     def __repr__(self):
#         return str(data)
    
#     def add_cpu(self, name, timestamp, value):
#         try:
#             self.data[name]["cpu"] = value
#             self.data[name]["cpu_timestamp"] = timestamp
#         except KeyError:
#             self.data[name] = {"cpu": value, "cpu_timestamp": timestamp}

#     def add_memory(self, name, timestamp, value):
#         try:
#             self.data[name]["memory"] = value
#             self.data[name]["memory_timestamp"] = timestamp
#         except KeyError:
#             self.data[name] = {"memory": value, "memory_timestamp": timestamp}

# class Containers:
#     def __init__(self):
#         self.data = {}

#     def __str__(self):
#         return str(data)
    
#     def __repr__(self):
#         return str(data)
    
#     def add_cpu(self, name, namespace, pod, timestamp, value):
#         try:
#             self.data[pod]["cpu"] = value
#             self.data[pod]["cpu_timestamp"] = timestamp
#         except KeyError:
#             self.data[pod] = {"namespace": namespace, "pod": pod, "container": name, "cpu": value, "cpu_timestamp": timestamp}

#     def add_memory(self, name, namespace, pod, timestamp, value):
#         try:
#             self.data[pod]["memory"] = value
#             self.data[pod]["memory_timestamp"] = timestamp
#         except KeyError:
#             self.data[pod] = {"namespace": namespace, "pod": pod, "container": name, "memory": value, "memory_timestamp": timestamp}

# %%
import json

config = json.load(open("config.json", "r"))

config
# Out:
# {'containers': {'compose-post-service': {'resources_target': {'cpu': 0.5,
#     'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'home-timeline-redis': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'home-timeline-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'jaeger': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'media-frontend': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'media-memcached': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'media-mongodb': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'media-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'nginx-thrift': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'post-storage-memcached': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'post-storage-mongodb': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'post-storage-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'social-graph-mongodb': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'social-graph-redis': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'social-graph-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'text-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'unique-id-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'url-shorten-memcached': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'url-shorten-mongodb': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'url-shorten-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-memcached': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-mention-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-mongodb': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-timeline-mongodb': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-timeline-redis': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5},
#   'user-timeline-service': {'resources_target': {'cpu': 0.5, 'memory': 512},
#    'min_replicas': 1,
#    'max_replicas': 5}},
#  'namespace': 'social-network'}

# %%
data = str(response[0])
rows = data.split("\n")

# Remove comments and empty lines
rows = [row for row in rows if not row.startswith("#") and row.strip() != ""]

# Split lines from rows
rows = [row.split() for row in rows]
from dataclass import PodMetric, ContainerMetric, NodeMetric
from typing import Dict
import time

def process_pod_or_container(row: list[str], pods: Dict[str, PodMetric], containers: Dict[str, ContainerMetric]):
    raw_name = row[0]
    value = row[1]
    timestamp = row[2]
    raw_type = raw_name.split("{")[0]
    pod = raw_name.split("\"")[-2].split("\"")[-1]
    namespace = raw_name.split("\"")[-4].split("\"")[-1]
    container = raw_name.split("\"")[1].split("\"")[0]
    match raw_type:
        case "container_cpu_usage_seconds_total":
            try:
                containers[pod].cpu_usage = value
                containers[pod].cpu_timestamp = timestamp
            except KeyError:
                containers[pod] = ContainerMetric(namespace=namespace, pod=pod, container=container)
                containers[pod].cpu_usage = value
                containers[pod].cpu_timestamp = timestamp
        case "container_memory_working_set_bytes":
            try:
                containers[pod].memory_usage = value
                containers[pod].memory_timestamp = timestamp
            except KeyError:
                containers[pod] = ContainerMetric(namespace=namespace, pod=pod, container=container)
                containers[pod].memory_usage = value
                containers[pod].memory_timestamp = timestamp
        case "pod_memory_working_set_bytes":
            try:
                pods[pod].memory_usage = value
                pods[pod].memory_timestamp = timestamp
            except KeyError:
                pods[pod] = PodMetric(namespace=namespace, pod=pod)
                pods[pod].memory_usage = value
                pods[pod].memory_timestamp = timestamp
        case "pod_cpu_usage_seconds_total":
            try:
                pods[pod].cpu_usage = value
                pods[pod].cpu_timestamp = timestamp
            except KeyError:
                pods[pod] = PodMetric(namespace=namespace, pod=pod)
                pods[pod].cpu_usage = value
                pods[pod].cpu_timestamp = timestamp


def process_node(row: list[str], nodes: Dict[str, NodeMetric], node_name: str):
    raw_type = row[0]
    value = row[1]
    timestamp = row[2]
    match raw_type:
        case "node_memory_working_set_bytes":
            try:
                nodes[node_names[current_node]].memory_usage = value 
                nodes[node_names[current_node]].memory_timestamp = timestamp 

            except KeyError:
                nodes[node_names[current_node]] = NodeMetric(name=node_name)
                nodes[node_names[current_node]].memory_usage = value
                nodes[node_names[current_node]].memory_timestamp = timestamp
        case "node_cpu_usage_seconds_total":
            try:
                nodes[node_names[current_node]].cpu_usage = value 
                nodes[node_names[current_node]].cpu_timestamp = timestamp 
            except KeyError:
                nodes[node_names[current_node]] = NodeMetric(name=node_name)
                nodes[node_names[current_node]].cpu_usage = value
                nodes[node_names[current_node]].cpu_timestamp = timestamp

import pandas as pd


    

from db import insert_batch_container_data, insert_batch_node_data, insert_batch_pod_data, connect
containers = {}

def test():
    pods = {}
    nodes = {}
    # containers = {}
    node_name = "minikube"
    for row in rows:
        try:
            if row[0] == "scrape_error":
                error_count = row[1]
            elif row[0][:4] == "node":
                process_node(row, nodes, node_name)
            else:
                process_pod_or_container(row, pods, containers)
                
        except IndexError:
            print("Error:",row)
    
    # conn = connect()
    # current_timestamp = time.time()
    # insert_batch_pod_data(conn, pods, current_timestamp)
    # insert_batch_container_data(conn, containers, current_timestamp)
    # insert_batch_node_data(conn, nodes, current_timestamp)
    # conn.close()
    print(containers)

test()
# Out:
# {'compose-post-service-866f6d7b74-hl962': ContainerMetric(pod='compose-post-service-866f6d7b74-hl962', container='compose-post-service', namespace='social-network', cpu_usage='338.52345', memory_usage='5.79584e+06', cpu_timestamp='1712920684063', memory_timestamp='1712920684063'), 'ingress-nginx-controller-7799c6795f-s4mkb': ContainerMetric(pod='ingress-nginx-controller-7799c6795f-s4mkb', container='controller', namespace='ingress-nginx', cpu_usage='192.415299', memory_usage='1.3252608e+08', cpu_timestamp='1712920683020', memory_timestamp='1712920683020'), 'coredns-5d78c9869d-lcldh': ContainerMetric(pod='coredns-5d78c9869d-lcldh', container='coredns', namespace='kube-system', cpu_usage='7.566781', memory_usage='2.248704e+07', cpu_timestamp='1712920683690', memory_timestamp='1712920683690'), 'etcd-minikube': ContainerMetric(pod='etcd-minikube', container='etcd', namespace='kube-system', cpu_usage='63.913114', memory_usage='6.6879488e+07', cpu_timestamp='1712920683789', memory_timestamp='1712920683789'), 'home-timeline-redis-7994f7cb85-d89c9': ContainerMetric(pod='home-timeline-redis-7994f7cb85-d89c9', container='home-timeline-redis', namespace='social-network', cpu_usage='152.79111', memory_usage='1.14845696e+09', cpu_timestamp='1712920684044', memory_timestamp='1712920684044'), 'home-timeline-service-bbc9bdd7b-cndcg': ContainerMetric(pod='home-timeline-service-bbc9bdd7b-cndcg', container='home-timeline-service', namespace='social-network', cpu_usage='62.106974', memory_usage='6.557696e+06', cpu_timestamp='1712920684169', memory_timestamp='1712920684169'), 'jaeger-7455bdbc47-jchjt': ContainerMetric(pod='jaeger-7455bdbc47-jchjt', container='jaeger', namespace='social-network', cpu_usage='46.203976', memory_usage='9.69633792e+08', cpu_timestamp='1712920683928', memory_timestamp='1712920683928'), 'kube-apiserver-minikube': ContainerMetric(pod='kube-apiserver-minikube', container='kube-apiserver', namespace='kube-system', cpu_usage='131.537513', memory_usage='2.61361664e+08', cpu_timestamp='1712920683802', memory_timestamp='1712920683802'), 'kube-controller-manager-minikube': ContainerMetric(pod='kube-controller-manager-minikube', container='kube-controller-manager', namespace='kube-system', cpu_usage='55.397913', memory_usage='5.9072512e+07', cpu_timestamp='1712920684045', memory_timestamp='1712920684045'), 'kube-proxy-p8wcq': ContainerMetric(pod='kube-proxy-p8wcq', container='kube-proxy', namespace='kube-system', cpu_usage='1.672111', memory_usage='2.7574272e+07', cpu_timestamp='1712920683984', memory_timestamp='1712920683984'), 'kube-scheduler-minikube': ContainerMetric(pod='kube-scheduler-minikube', container='kube-scheduler', namespace='kube-system', cpu_usage='9.207513', memory_usage='2.3814144e+07', cpu_timestamp='1712920683861', memory_timestamp='1712920683861'), 'media-frontend-7f4999dcd-n64xn': ContainerMetric(pod='media-frontend-7f4999dcd-n64xn', container='media-frontend', namespace='social-network', cpu_usage='0.061269', memory_usage='1.5839232e+07', cpu_timestamp='1712920684574', memory_timestamp='1712920684574'), 'media-memcached-7c887f8cc6-l5q56': ContainerMetric(pod='media-memcached-7c887f8cc6-l5q56', container='media-memcached', namespace='social-network', cpu_usage='0.556675', memory_usage='1.14688e+06', cpu_timestamp='1712920684005', memory_timestamp='1712920684005'), 'media-mongodb-cb6857b9f-gwf5w': ContainerMetric(pod='media-mongodb-cb6857b9f-gwf5w', container='media-mongodb', namespace='social-network', cpu_usage='17.066165', memory_usage='3.8559744e+07', cpu_timestamp='1712920684131', memory_timestamp='1712920684131'), 'media-service-7848df64c4-74h8s': ContainerMetric(pod='media-service-7848df64c4-74h8s', container='media-service', namespace='social-network', cpu_usage='23.264332', memory_usage='1.830912e+06', cpu_timestamp='1712920684098', memory_timestamp='1712920684098'), 'metrics-server-7746886d4f-cnvs4': ContainerMetric(pod='metrics-server-7746886d4f-cnvs4', container='metrics-server', namespace='kube-s ...

# %%
containers
# Out:
# {'compose-post-service-866f6d7b74-hl962': ContainerMetric(pod='compose-post-service-866f6d7b74-hl962', container='compose-post-service', namespace='social-network', cpu_usage='338.52345', memory_usage='5.79584e+06', cpu_timestamp='1712920684063', memory_timestamp='1712920684063'),
#  'ingress-nginx-controller-7799c6795f-s4mkb': ContainerMetric(pod='ingress-nginx-controller-7799c6795f-s4mkb', container='controller', namespace='ingress-nginx', cpu_usage='192.415299', memory_usage='1.3252608e+08', cpu_timestamp='1712920683020', memory_timestamp='1712920683020'),
#  'coredns-5d78c9869d-lcldh': ContainerMetric(pod='coredns-5d78c9869d-lcldh', container='coredns', namespace='kube-system', cpu_usage='7.566781', memory_usage='2.248704e+07', cpu_timestamp='1712920683690', memory_timestamp='1712920683690'),
#  'etcd-minikube': ContainerMetric(pod='etcd-minikube', container='etcd', namespace='kube-system', cpu_usage='63.913114', memory_usage='6.6879488e+07', cpu_timestamp='1712920683789', memory_timestamp='1712920683789'),
#  'home-timeline-redis-7994f7cb85-d89c9': ContainerMetric(pod='home-timeline-redis-7994f7cb85-d89c9', container='home-timeline-redis', namespace='social-network', cpu_usage='152.79111', memory_usage='1.14845696e+09', cpu_timestamp='1712920684044', memory_timestamp='1712920684044'),
#  'home-timeline-service-bbc9bdd7b-cndcg': ContainerMetric(pod='home-timeline-service-bbc9bdd7b-cndcg', container='home-timeline-service', namespace='social-network', cpu_usage='62.106974', memory_usage='6.557696e+06', cpu_timestamp='1712920684169', memory_timestamp='1712920684169'),
#  'jaeger-7455bdbc47-jchjt': ContainerMetric(pod='jaeger-7455bdbc47-jchjt', container='jaeger', namespace='social-network', cpu_usage='46.203976', memory_usage='9.69633792e+08', cpu_timestamp='1712920683928', memory_timestamp='1712920683928'),
#  'kube-apiserver-minikube': ContainerMetric(pod='kube-apiserver-minikube', container='kube-apiserver', namespace='kube-system', cpu_usage='131.537513', memory_usage='2.61361664e+08', cpu_timestamp='1712920683802', memory_timestamp='1712920683802'),
#  'kube-controller-manager-minikube': ContainerMetric(pod='kube-controller-manager-minikube', container='kube-controller-manager', namespace='kube-system', cpu_usage='55.397913', memory_usage='5.9072512e+07', cpu_timestamp='1712920684045', memory_timestamp='1712920684045'),
#  'kube-proxy-p8wcq': ContainerMetric(pod='kube-proxy-p8wcq', container='kube-proxy', namespace='kube-system', cpu_usage='1.672111', memory_usage='2.7574272e+07', cpu_timestamp='1712920683984', memory_timestamp='1712920683984'),
#  'kube-scheduler-minikube': ContainerMetric(pod='kube-scheduler-minikube', container='kube-scheduler', namespace='kube-system', cpu_usage='9.207513', memory_usage='2.3814144e+07', cpu_timestamp='1712920683861', memory_timestamp='1712920683861'),
#  'media-frontend-7f4999dcd-n64xn': ContainerMetric(pod='media-frontend-7f4999dcd-n64xn', container='media-frontend', namespace='social-network', cpu_usage='0.061269', memory_usage='1.5839232e+07', cpu_timestamp='1712920684574', memory_timestamp='1712920684574'),
#  'media-memcached-7c887f8cc6-l5q56': ContainerMetric(pod='media-memcached-7c887f8cc6-l5q56', container='media-memcached', namespace='social-network', cpu_usage='0.556675', memory_usage='1.14688e+06', cpu_timestamp='1712920684005', memory_timestamp='1712920684005'),
#  'media-mongodb-cb6857b9f-gwf5w': ContainerMetric(pod='media-mongodb-cb6857b9f-gwf5w', container='media-mongodb', namespace='social-network', cpu_usage='17.066165', memory_usage='3.8559744e+07', cpu_timestamp='1712920684131', memory_timestamp='1712920684131'),
#  'media-service-7848df64c4-74h8s': ContainerMetric(pod='media-service-7848df64c4-74h8s', container='media-service', namespace='social-network', cpu_usage='23.264332', memory_usage='1.830912e+06', cpu_timestamp='1712920684098', memory_timestamp='1712920684098'),
#  'metrics-server-7746886d4f-cnvs4': ContainerMetric(pod='metrics-server-7746886d4f-cnvs4', container='metrics-server', namespace='kube-system', cpu_usage='10.637611', memory_usage='3.209216e+07', cpu_timestamp='1712920683883', memory_timestamp='1712920683883'),
#  'nginx-thrift-57fdb4c4f9-qn6tv': ContainerMetric(pod='nginx-thrift-57fdb4c4f9-qn6tv', container='nginx-thrift', namespace='social-network', cpu_usage='178.615305', memory_usage='5.8638336e+07', cpu_timestamp='1712920684414', memory_timestamp='1712920684414'),
#  'post-storage-memcached-675b5c57bd-smb49': ContainerMetric(pod='post-storage-memcached-675b5c57bd-smb49', container='post-storage-memcached', namespace='social-network', cpu_usage='0.57131', memory_usage='1.138688e+06', cpu_timestamp='1712920684055', memory_timestamp='1712920684055'),
#  'post-storage-mongodb-5d7bfcd455-t6sdz': ContainerMetric(pod='post-storage-mongodb-5d7bfcd455-t6sdz', container='post-storage-mongodb', namespace='social-network', cpu_usage='89.092198', memory_usage='2.81198592e+08', cpu_timestamp='1712920684082', memory_timestamp='1712920684082'),
#  'post-storage-service-84b659876c-7tt26': ContainerMetric(pod='post-storage-service-84b659876c-7tt26', container='post-storage-service', namespace='social-network', cpu_usage='51.55697', memory_usage='4.022272e+06', cpu_timestamp='1712920684105', memory_timestamp='1712920684105'),
#  'social-graph-mongodb-78b95799d7-856w7': ContainerMetric(pod='social-graph-mongodb-78b95799d7-856w7', container='social-graph-mongodb', namespace='social-network', cpu_usage='50.311419', memory_usage='1.4475264e+08', cpu_timestamp='1712920684107', memory_timestamp='1712920684107'),
#  'social-graph-redis-7d9b494f66-px74j': ContainerMetric(pod='social-graph-redis-7d9b494f66-px74j', container='social-graph-redis', namespace='social-network', cpu_usage='22.134518', memory_usage='9.388032e+06', cpu_timestamp='1712920684080', memory_timestamp='1712920684080'),
#  'social-graph-service-55b7888dc7-b6jzj': ContainerMetric(pod='social-graph-service-55b7888dc7-b6jzj', container='social-graph-service', namespace='social-network', cpu_usage='81.549663', memory_usage='2.4649728e+07', cpu_timestamp='1712920684080', memory_timestamp='1712920684080'),
#  'storage-provisioner': ContainerMetric(pod='storage-provisioner', container='storage-provisioner', namespace='kube-system', cpu_usage='7.627386', memory_usage='1.734656e+07', cpu_timestamp='1712920683681', memory_timestamp='1712920683681'),
#  'text-service-76cf6557f7-zxtdn': ContainerMetric(pod='text-service-76cf6557f7-zxtdn', container='text-service', namespace='social-network', cpu_usage='176.937929', memory_usage='6.627328e+06', cpu_timestamp='1712920684201', memory_timestamp='1712920684201'),
#  'unique-id-service-6b88dd4658-fzx7l': ContainerMetric(pod='unique-id-service-6b88dd4658-fzx7l', container='unique-id-service', namespace='social-network', cpu_usage='24.486269', memory_usage='1.646592e+06', cpu_timestamp='1712920684124', memory_timestamp='1712920684124'),
#  'url-shorten-memcached-55d47ccc88-7qv4c': ContainerMetric(pod='url-shorten-memcached-55d47ccc88-7qv4c', container='url-shorten-memcached', namespace='social-network', cpu_usage='0.554496', memory_usage='1.134592e+06', cpu_timestamp='1712920683995', memory_timestamp='1712920683995'),
#  'url-shorten-mongodb-5697666656-cj7vm': ContainerMetric(pod='url-shorten-mongodb-5697666656-cj7vm', container='url-shorten-mongodb', namespace='social-network', cpu_usage='123.388703', memory_usage='2.96341504e+08', cpu_timestamp='1712920684172', memory_timestamp='1712920684172'),
#  'url-shorten-service-6d8bbf75f8-dgrh6': ContainerMetric(pod='url-shorten-service-6d8bbf75f8-dgrh6', container='url-shorten-service', namespace='social-network', cpu_usage='85.140501', memory_usage='5.287936e+06', cpu_timestamp='1712920684069', memory_timestamp='1712920684069'),
#  'user-memcached-67b7d46c5b-gsgk4': ContainerMetric(pod='user-memcached-67b7d46c5b-gsgk4', container='user-memcached', namespace='social-network', cpu_usage='39.084292', memory_usage='4.251648e+06', cpu_timestamp='1712920684006', memory_timestamp='1712920684006'),
#  'user-mention-service-764c7d97c5-7rw64': ContainerMetric(pod='user-mention-service-764c7d97c5-7rw64', container='user-mention-service', namespace='social-network', cpu_usage='64.825606', memory_usage='3.313664e+06', cpu_timestamp='1712920684095', memory_timestamp='1712920684095'),
#  'user-mongodb-86bb4559d-nmlch': ContainerMetric(pod='user-mongodb-86bb4559d-nmlch', container='user-mongodb', namespace='social-network', cpu_usage='34.339431', memory_usage='8.404992e+07', cpu_timestamp='1712920684108', memory_timestamp='1712920684108'),
#  'user-service-74685b9465-8qlhb': ContainerMetric(pod='user-service-74685b9465-8qlhb', container='user-service', namespace='social-network', cpu_usage='27.893279', memory_usage='1.3340672e+07', cpu_timestamp='1712920684178', memory_timestamp='1712920684178'),
#  'user-timeline-mongodb-687f6576fb-m94rm': ContainerMetric(pod='user-timeline-mongodb-687f6576fb-m94rm', container='user-timeline-mongodb', namespace='social-network', cpu_usage='165.39237', memory_usage='1.62205696e+08', cpu_timestamp='1712920684095', memory_timestamp='1712920684095'),
#  'user-timeline-redis-6bf758cc4f-5mndw': ContainerMetric(pod='user-timeline-redis-6bf758cc4f-5mndw', container='user-timeline-redis', namespace='social-network', cpu_usage='22.363643', memory_usage='4.6125056e+07', cpu_timestamp='1712920684122', memory_timestamp='1712920684122'),
#  'user-timeline-service-65d5766796-2wnnp': ContainerMetric(pod='user-timeline-service-65d5766796-2wnnp', container='user-timeline-service', namespace='social-network', cpu_usage='60.944344', memory_usage='5.984256e+06', cpu_timestamp='1712920684052', memory_timestamp='1712920684052')}

# %%
config["containers"].keys()
# Out:
# dict_keys(['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service'])

# %%
data = pd.DataFrame(columns=["container", *config["containers"].keys()])
data
# Out:
# Empty DataFrame
# Columns: [container, compose-post-service, home-timeline-redis, home-timeline-service, jaeger, media-frontend, media-memcached, media-mongodb, media-service, nginx-thrift, post-storage-memcached, post-storage-mongodb, post-storage-service, social-graph-mongodb, social-graph-redis, social-graph-service, text-service, unique-id-service, url-shorten-memcached, url-shorten-mongodb, url-shorten-service, user-memcached, user-mention-service, user-mongodb, user-service, user-timeline-mongodb, user-timeline-redis, user-timeline-service]
# Index: []
#
# [0 rows x 28 columns]

# %%
def transform_container(containers: Dict[str, ContainerMetric]):
    data = pd.DataFrame(containers.values(), columns=ContainerMetric.__annotations__.keys())
    data["timestamp"] = int(time.time())
    print(data.groupby("container").first())


transform_container(containers)
# Out:
#                                                                pod  \
# container
# compose-post-service         compose-post-service-866f6d7b74-hl962
# controller               ingress-nginx-controller-7799c6795f-s4mkb
# coredns                                   coredns-5d78c9869d-lcldh
# etcd                                                 etcd-minikube
# home-timeline-redis           home-timeline-redis-7994f7cb85-d89c9
# home-timeline-service        home-timeline-service-bbc9bdd7b-cndcg
# jaeger                                     jaeger-7455bdbc47-jchjt
# kube-apiserver                             kube-apiserver-minikube
# kube-controller-manager           kube-controller-manager-minikube
# kube-proxy                                        kube-proxy-p8wcq
# kube-scheduler                             kube-scheduler-minikube
# media-frontend                      media-frontend-7f4999dcd-n64xn
# media-memcached                   media-memcached-7c887f8cc6-l5q56
# media-mongodb                        media-mongodb-cb6857b9f-gwf5w
# media-service                       media-service-7848df64c4-74h8s
# metrics-server                     metrics-server-7746886d4f-cnvs4
# nginx-thrift                         nginx-thrift-57fdb4c4f9-qn6tv
# post-storage-memcached     post-storage-memcached-675b5c57bd-smb49
# post-storage-mongodb         post-storage-mongodb-5d7bfcd455-t6sdz
# post-storage-service         post-storage-service-84b659876c-7tt26
# social-graph-mongodb         social-graph-mongodb-78b95799d7-856w7
# social-graph-redis             social-graph-redis-7d9b494f66-px74j
# social-graph-service         social-graph-service-55b7888dc7-b6jzj
# storage-provisioner                            storage-provisioner
# text-service                         text-service-76cf6557f7-zxtdn
# unique-id-service               unique-id-service-6b88dd4658-fzx7l
# url-shorten-memcached       url-shorten-memcached-55d47ccc88-7qv4c
# url-shorten-mongodb           url-shorten-mongodb-5697666656-cj7vm
# url-shorten-service           url-shorten-service-6d8bbf75f8-dgrh6
# user-memcached                     user-memcached-67b7d46c5b-gsgk4
# user-mention-service         user-mention-service-764c7d97c5-7rw64
# user-mongodb                          user-mongodb-86bb4559d-nmlch
# user-service                         user-service-74685b9465-8qlhb
# user-timeline-mongodb       user-timeline-mongodb-687f6576fb-m94rm
# user-timeline-redis           user-timeline-redis-6bf758cc4f-5mndw
# user-timeline-service       user-timeline-service-65d5766796-2wnnp
#
#                               namespace   cpu_usage    memory_usage  \
# container
# compose-post-service     social-network   338.52345     5.79584e+06
# controller                ingress-nginx  192.415299   1.3252608e+08
# coredns                     kube-system    7.566781    2.248704e+07
# etcd                        kube-system   63.913114   6.6879488e+07
# home-timeline-redis      social-network   152.79111  1.14845696e+09
# home-timeline-service    social-network   62.106974    6.557696e+06
# jaeger                   social-network   46.203976  9.69633792e+08
# kube-apiserver              kube-system  131.537513  2.61361664e+08
# kube-controller-manager     kube-system   55.397913   5.9072512e+07
# kube-proxy                  kube-system    1.672111   2.7574272e+07
# kube-scheduler              kube-system    9.207513   2.3814144e+07
# media-frontend           social-network    0.061269   1.5839232e+07
# media-memcached          social-network    0.556675     1.14688e+06
# media-mongodb            social-network   17.066165   3.8559744e+07
# media-service            social-network   23.264332    1.830912e+06
# metrics-server              kube-system   10.637611    3.209216e+07
# nginx-thrift             social-network  178.615305   5.8638336e+07
# post-storage-memcached   social-network     0.57131    1.138688e+06
# post-storage-mongodb     social-network   89.092198  2.81198592e+08
# post-storage-service     social-network    51.55697    4.022272e+06
# social-graph-mongodb     social-network   50.311419   1.4475264e+08
# social-graph-redis       social-network   22.134518    9.388032e+06
# social-graph-service     social-network   81.549663   2.4649728e+07
# storage-provisioner         kube-system    7.627386    1.734656e+07
# text-service             social-network  176.937929    6.627328e+06
# unique-id-service        social-network   24.486269    1.646592e+06
# url-shorten-memcached    social-network    0.554496    1.134592e+06
# url-shorten-mongodb      social-network  123.388703  2.96341504e+08
# url-shorten-service      social-network   85.140501    5.287936e+06
# user-memcached           social-network   39.084292    4.251648e+06
# user-mention-service     social-network   64.825606    3.313664e+06
# user-mongodb             social-network   34.339431    8.404992e+07
# user-service             social-network   27.893279   1.3340672e+07
# user-timeline-mongodb    social-network   165.39237  1.62205696e+08
# user-timeline-redis      social-network   22.363643   4.6125056e+07
# user-timeline-service    social-network   60.944344    5.984256e+06
#
#                          cpu_timestamp memory_timestamp   timestamp
# container
# compose-post-service     1712920684063    1712920684063  1712924016
# controller               1712920683020    1712920683020  1712924016
# coredns                  1712920683690    1712920683690  1712924016
# etcd                     1712920683789    1712920683789  1712924016
# home-timeline-redis      1712920684044    1712920684044  1712924016
# home-timeline-service    1712920684169    1712920684169  1712924016
# jaeger                   1712920683928    1712920683928  1712924016
# kube-apiserver           1712920683802    1712920683802  1712924016
# kube-controller-manager  1712920684045    1712920684045  1712924016
# kube-proxy               1712920683984    1712920683984  1712924016
# kube-scheduler           1712920683861    1712920683861  1712924016
# media-frontend           1712920684574    1712920684574  1712924016
# media-memcached          1712920684005    1712920684005  1712924016
# media-mongodb            1712920684131    1712920684131  1712924016
# media-service            1712920684098    1712920684098  1712924016
# metrics-server           1712920683883    1712920683883  1712924016
# nginx-thrift             1712920684414    1712920684414  1712924016
# post-storage-memcached   1712920684055    1712920684055  1712924016
# post-storage-mongodb     1712920684082    1712920684082  1712924016
# post-storage-service     1712920684105    1712920684105  1712924016
# social-graph-mongodb     1712920684107    1712920684107  1712924016
# social-graph-redis       1712920684080    1712920684080  1712924016
# social-graph-service     1712920684080    1712920684080  1712924016
# storage-provisioner      1712920683681    1712920683681  1712924016
# text-service             1712920684201    1712920684201  1712924016
# unique-id-service        1712920684124    1712920684124  1712924016
# url-shorten-memcached    1712920683995    1712920683995  1712924016
# url-shorten-mongodb      1712920684172    1712920684172  1712924016
# url-shorten-service      1712920684069    1712920684069  1712924016
# user-memcached           1712920684006    1712920684006  1712924016
# user-mention-service     1712920684095    1712920684095  1712924016
# user-mongodb             1712920684108    1712920684108  1712924016
# user-service             1712920684178    1712920684178  1712924016
# user-timeline-mongodb    1712920684095    1712920684095  1712924016
# user-timeline-redis      1712920684122    1712920684122  1712924016
# user-timeline-service    1712920684052    1712920684052  1712924016

# %%
def transform_container(containers: Dict[str, ContainerMetric]):
    data = pd.DataFrame(containers.values(), columns=ContainerMetric.__annotations__.keys())
    data = data.loc[data["container"].isin(config["containers"].keys())]
    data["timestamp"] = int(time.time())
    data.drop(["pod", "namespace"], axis=1, inplace=True)
    data = data.groupby("container").sum().reset_index()
    data = data.pivot(index="timestamp", columns="container", values=['cpu_usage', 'memory_usage'])
    data.columns = [f'{col[0]}_{col[1]}' for col in data.columns]
    return data
        
transform_container(containers)
# Out:
#            cpu_usage_compose-post-service cpu_usage_home-timeline-redis  \
# timestamp
# 1712926466                      338.52345                     152.79111
#
#            cpu_usage_home-timeline-service cpu_usage_jaeger  \
# timestamp
# 1712926466                       62.106974        46.203976
#
#            cpu_usage_media-frontend cpu_usage_media-memcached  \
# timestamp
# 1712926466                 0.061269                  0.556675
#
#            cpu_usage_media-mongodb cpu_usage_media-service  \
# timestamp
# 1712926466               17.066165               23.264332
#
#            cpu_usage_nginx-thrift cpu_usage_post-storage-memcached  ...  \
# timestamp                                                           ...
# 1712926466             178.615305                          0.57131  ...
#
#            memory_usage_url-shorten-memcached  \
# timestamp
# 1712926466                       1.134592e+06
#
#            memory_usage_url-shorten-mongodb memory_usage_url-shorten-service  \
# timestamp
# 1712926466                   2.96341504e+08                     5.287936e+06
#
#            memory_usage_user-memcached memory_usage_user-mention-service  \
# timestamp
# 1712926466                4.251648e+06                      3.313664e+06
#
#            memory_usage_user-mongodb memory_usage_user-service  \
# timestamp
# 1712926466              8.404992e+07             1.3340672e+07
#
#            memory_usage_user-timeline-mongodb  \
# timestamp
# 1712926466                     1.62205696e+08
#
#            memory_usage_user-timeline-redis memory_usage_user-timeline-service
# timestamp
# 1712926466                    4.6125056e+07                       5.984256e+06
#
# [1 rows x 54 columns]

# %%
containers.values()
# Out:
# dict_values([ContainerMetric(pod='compose-post-service-866f6d7b74-hl962', container='compose-post-service', namespace='social-network', cpu_usage='338.52345', memory_usage='5.79584e+06', cpu_timestamp='1712920684063', memory_timestamp='1712920684063'), ContainerMetric(pod='ingress-nginx-controller-7799c6795f-s4mkb', container='controller', namespace='ingress-nginx', cpu_usage='192.415299', memory_usage='1.3252608e+08', cpu_timestamp='1712920683020', memory_timestamp='1712920683020'), ContainerMetric(pod='coredns-5d78c9869d-lcldh', container='coredns', namespace='kube-system', cpu_usage='7.566781', memory_usage='2.248704e+07', cpu_timestamp='1712920683690', memory_timestamp='1712920683690'), ContainerMetric(pod='etcd-minikube', container='etcd', namespace='kube-system', cpu_usage='63.913114', memory_usage='6.6879488e+07', cpu_timestamp='1712920683789', memory_timestamp='1712920683789'), ContainerMetric(pod='home-timeline-redis-7994f7cb85-d89c9', container='home-timeline-redis', namespace='social-network', cpu_usage='152.79111', memory_usage='1.14845696e+09', cpu_timestamp='1712920684044', memory_timestamp='1712920684044'), ContainerMetric(pod='home-timeline-service-bbc9bdd7b-cndcg', container='home-timeline-service', namespace='social-network', cpu_usage='62.106974', memory_usage='6.557696e+06', cpu_timestamp='1712920684169', memory_timestamp='1712920684169'), ContainerMetric(pod='jaeger-7455bdbc47-jchjt', container='jaeger', namespace='social-network', cpu_usage='46.203976', memory_usage='9.69633792e+08', cpu_timestamp='1712920683928', memory_timestamp='1712920683928'), ContainerMetric(pod='kube-apiserver-minikube', container='kube-apiserver', namespace='kube-system', cpu_usage='131.537513', memory_usage='2.61361664e+08', cpu_timestamp='1712920683802', memory_timestamp='1712920683802'), ContainerMetric(pod='kube-controller-manager-minikube', container='kube-controller-manager', namespace='kube-system', cpu_usage='55.397913', memory_usage='5.9072512e+07', cpu_timestamp='1712920684045', memory_timestamp='1712920684045'), ContainerMetric(pod='kube-proxy-p8wcq', container='kube-proxy', namespace='kube-system', cpu_usage='1.672111', memory_usage='2.7574272e+07', cpu_timestamp='1712920683984', memory_timestamp='1712920683984'), ContainerMetric(pod='kube-scheduler-minikube', container='kube-scheduler', namespace='kube-system', cpu_usage='9.207513', memory_usage='2.3814144e+07', cpu_timestamp='1712920683861', memory_timestamp='1712920683861'), ContainerMetric(pod='media-frontend-7f4999dcd-n64xn', container='media-frontend', namespace='social-network', cpu_usage='0.061269', memory_usage='1.5839232e+07', cpu_timestamp='1712920684574', memory_timestamp='1712920684574'), ContainerMetric(pod='media-memcached-7c887f8cc6-l5q56', container='media-memcached', namespace='social-network', cpu_usage='0.556675', memory_usage='1.14688e+06', cpu_timestamp='1712920684005', memory_timestamp='1712920684005'), ContainerMetric(pod='media-mongodb-cb6857b9f-gwf5w', container='media-mongodb', namespace='social-network', cpu_usage='17.066165', memory_usage='3.8559744e+07', cpu_timestamp='1712920684131', memory_timestamp='1712920684131'), ContainerMetric(pod='media-service-7848df64c4-74h8s', container='media-service', namespace='social-network', cpu_usage='23.264332', memory_usage='1.830912e+06', cpu_timestamp='1712920684098', memory_timestamp='1712920684098'), ContainerMetric(pod='metrics-server-7746886d4f-cnvs4', container='metrics-server', namespace='kube-system', cpu_usage='10.637611', memory_usage='3.209216e+07', cpu_timestamp='1712920683883', memory_timestamp='1712920683883'), ContainerMetric(pod='nginx-thrift-57fdb4c4f9-qn6tv', container='nginx-thrift', namespace='social-network', cpu_usage='178.615305', memory_usage='5.8638336e+07', cpu_timestamp='1712920684414', memory_timestamp='1712920684414'), ContainerMetric(pod='post-storage-memcached-675b5c57bd-smb49', container='post-storage-memcached', namespace='social-network', cpu_usage='0.57131', memory_u ...

# %%
rows
# Out:
# [['container_cpu_usage_seconds_total{container="cast-info-memcached",namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"}',
#   '1.863737',
#   '1709119445656'],
#  ['container_cpu_usage_seconds_total{container="cast-info-mongodb",namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"}',
#   '67.178791',
#   '1709119445662'],
#  ['container_cpu_usage_seconds_total{container="cast-info-service",namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"}',
#   '2.303045',
#   '1709119446795'],
#  ['container_cpu_usage_seconds_total{container="compose-review-memcached",namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"}',
#   '69.726172',
#   '1709119445446'],
#  ['container_cpu_usage_seconds_total{container="compose-review-service",namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"}',
#   '311.354159',
#   '1709119446675'],
#  ['container_cpu_usage_seconds_total{container="coredns",namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"}',
#   '22.318655',
#   '1709119445257'],
#  ['container_cpu_usage_seconds_total{container="etcd",namespace="kube-system",pod="etcd-minikube"}',
#   '212.605829',
#   '1709119445294'],
#  ['container_cpu_usage_seconds_total{container="jaeger",namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"}',
#   '5.504502',
#   '1709119445160'],
#  ['container_cpu_usage_seconds_total{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"}',
#   '545.506491',
#   '1709119445274'],
#  ['container_cpu_usage_seconds_total{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"}',
#   '166.890547',
#   '1709119445458'],
#  ['container_cpu_usage_seconds_total{container="kube-proxy",namespace="kube-system",pod="kube-proxy-ht6xb"}',
#   '5.253829',
#   '1709119445394'],
#  ['container_cpu_usage_seconds_total{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"}',
#   '33.529098',
#   '1709119445384'],
#  ['container_cpu_usage_seconds_total{container="kube-state-metrics",namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"}',
#   '6.450919',
#   '1709119445371'],
#  ['container_cpu_usage_seconds_total{container="movie-id-memcached",namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"}',
#   '15.200365',
#   '1709119445510'],
#  ['container_cpu_usage_seconds_total{container="movie-id-mongodb",namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"}',
#   '65.375776',
#   '1709119445718'],
#  ['container_cpu_usage_seconds_total{container="movie-id-service",namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"}',
#   '143.267642',
#   '1709119446757'],
#  ['container_cpu_usage_seconds_total{container="movie-info-memcached",namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"}',
#   '1.869352',
#   '1709119445663'],
#  ['container_cpu_usage_seconds_total{container="movie-info-mongodb",namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"}',
#   '64.755947',
#   '1709119445673'],
#  ['container_cpu_usage_seconds_total{container="movie-info-service",namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"}',
#   '0.49642',
#   '1709119446713'],
#  ['container_cpu_usage_seconds_total{container="movie-review-mongodb",namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"}',
#   '190.114068',
#   '1709119445663'],
#  ['container_cpu_usage_seconds_total{container="movie-review-redis",namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"}',
#   '34.030269',
#   '1709119445567'],
#  ['container_cpu_usage_seconds_total{container="movie-review-service",namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"}',
#   '90.569391',
#   '1709119446767'],
#  ['container_cpu_usage_seconds_total{container="nginx-web-server",namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"}',
#   '164.359209',
#   '1709119446094'],
#  ['container_cpu_usage_seconds_total{container="page-service",namespace="media-microservices",pod="page-service-54b69789b-6zgfz"}',
#   '0.051373',
#   '1709119446688'],
#  ['container_cpu_usage_seconds_total{container="plot-memcached",namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"}',
#   '1.884198',
#   '1709119445653'],
#  ['container_cpu_usage_seconds_total{container="plot-mongodb",namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"}',
#   '65.045088',
#   '1709119445664'],
#  ['container_cpu_usage_seconds_total{container="plot-service",namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"}',
#   '0.450149',
#   '1709119446707'],
#  ['container_cpu_usage_seconds_total{container="rating-redis",namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"}',
#   '40.263121',
#   '1709119445509'],
#  ['container_cpu_usage_seconds_total{container="rating-service",namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"}',
#   '117.743538',
#   '1709119446762'],
#  ['container_cpu_usage_seconds_total{container="review-storage-memcached",namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"}',
#   '1.848227',
#   '1709119445635'],
#  ['container_cpu_usage_seconds_total{container="review-storage-mongodb",namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"}',
#   '103.28414',
#   '1709119445710'],
#  ['container_cpu_usage_seconds_total{container="review-storage-service",namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"}',
#   '39.464775',
#   '1709119446709'],
#  ['container_cpu_usage_seconds_total{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"}',
#   '26.039186',
#   '1709119445160'],
#  ['container_cpu_usage_seconds_total{container="text-service",namespace="media-microservices",pod="text-service-6949778f76-jwsh9"}',
#   '29.03914',
#   '1709119446661'],
#  ['container_cpu_usage_seconds_total{container="unique-id-service",namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"}',
#   '41.40195',
#   '1709119446795'],
#  ['container_cpu_usage_seconds_total{container="user-memcached",namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"}',
#   '9.478635',
#   '1709119445460'],
#  ['container_cpu_usage_seconds_total{container="user-mongodb",namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"}',
#   '65.616766',
#   '1709119445620'],
#  ['container_cpu_usage_seconds_total{container="user-review-mongodb",namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"}',
#   '187.168981',
#   '1709119445550'],
#  ['container_cpu_usage_seconds_total{container="user-review-redis",namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"}',
#   '34.153041',
#   '1709119445656'],
#  ['container_cpu_usage_seconds_total{container="user-review-service",namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"}',
#   '91.398774',
#   '1709119446696'],
#  ['container_cpu_usage_seconds_total{container="user-service",namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"}',
#   '49.744881',
#   '1709119446715'],
#  ['container_memory_working_set_bytes{container="cast-info-memcached",namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"}',
#   '1.347584e+06',
#   '1709119445656'],
#  ['container_memory_working_set_bytes{container="cast-info-mongodb",namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"}',
#   '8.5778432e+07',
#   '1709119445662'],
#  ['container_memory_working_set_bytes{container="cast-info-service",namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"}',
#   '1.8075648e+07',
#   '1709119446795'],
#  ['container_memory_working_set_bytes{container="compose-review-memcached",namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"}',
#   '1.540096e+07',
#   '1709119445446'],
#  ['container_memory_working_set_bytes{container="compose-review-service",namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"}',
#   '1.6297984e+07',
#   '1709119446675'],
#  ['container_memory_working_set_bytes{container="coredns",namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"}',
#   '4.13696e+07',
#   '1709119445257'],
#  ['container_memory_working_set_bytes{container="etcd",namespace="kube-system",pod="etcd-minikube"}',
#   '5.689344e+07',
#   '1709119445294'],
#  ['container_memory_working_set_bytes{container="jaeger",namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"}',
#   '1.05877504e+08',
#   '1709119445160'],
#  ['container_memory_working_set_bytes{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"}',
#   '2.63061504e+08',
#   '1709119445274'],
#  ['container_memory_working_set_bytes{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"}',
#   '6.803456e+07',
#   '1709119445458'],
#  ['container_memory_working_set_bytes{container="kube-proxy",namespace="kube-system",pod="kube-proxy-ht6xb"}',
#   '2.7869184e+07',
#   '1709119445394'],
#  ['container_memory_working_set_bytes{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"}',
#   '3.5770368e+07',
#   '1709119445384'],
#  ['container_memory_working_set_bytes{container="kube-state-metrics",namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"}',
#   '2.0983808e+07',
#   '1709119445371'],
#  ['container_memory_working_set_bytes{container="movie-id-memcached",namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"}',
#   '7.069696e+06',
#   '1709119445510'],
#  ['container_memory_working_set_bytes{container="movie-id-mongodb",namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"}',
#   '3.9108608e+07',
#   '1709119445718'],
#  ['container_memory_working_set_bytes{container="movie-id-service",namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"}',
#   '7.991296e+06',
#   '1709119446757'],
#  ['container_memory_working_set_bytes{container="movie-info-memcached",namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"}',
#   '1.150976e+06',
#   '1709119445663'],
#  ['container_memory_working_set_bytes{container="movie-info-mongodb",namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"}',
#   '2.4756224e+07',
#   '1709119445673'],
#  ['container_memory_working_set_bytes{container="movie-info-service",namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"}',
#   '8.163328e+06',
#   '1709119446713'],
#  ['container_memory_working_set_bytes{container="movie-review-mongodb",namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"}',
#   '1.40890112e+08',
#   '1709119445663'],
#  ['container_memory_working_set_bytes{container="movie-review-redis",namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"}',
#   '2.904064e+06',
#   '1709119445567'],
#  ['container_memory_working_set_bytes{container="movie-review-service",namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"}',
#   '1.2857344e+07',
#   '1709119446767'],
#  ['container_memory_working_set_bytes{container="nginx-web-server",namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"}',
#   '2.4629248e+07',
#   '1709119446094'],
#  ['container_memory_working_set_bytes{container="page-service",namespace="media-microservices",pod="page-service-54b69789b-6zgfz"}',
#   '839680',
#   '1709119446688'],
#  ['container_memory_working_set_bytes{container="plot-memcached",namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"}',
#   '1.134592e+06',
#   '1709119445653'],
#  ['container_memory_working_set_bytes{container="plot-mongodb",namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"}',
#   '2.5464832e+07',
#   '1709119445664'],
#  ['container_memory_working_set_bytes{container="plot-service",namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"}',
#   '6.475776e+06',
#   '1709119446707'],
#  ['container_memory_working_set_bytes{container="rating-redis",namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"}',
#   '6.7584e+06',
#   '1709119445509'],
#  ['container_memory_working_set_bytes{container="rating-service",namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"}',
#   '9.613312e+06',
#   '1709119446762'],
#  ['container_memory_working_set_bytes{container="review-storage-memcached",namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"}',
#   '1.159168e+06',
#   '1709119445635'],
#  ['container_memory_working_set_bytes{container="review-storage-mongodb",namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"}',
#   '2.0717568e+08',
#   '1709119445710'],
#  ['container_memory_working_set_bytes{container="review-storage-service",namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"}',
#   '4.820992e+06',
#   '1709119446709'],
#  ['container_memory_working_set_bytes{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"}',
#   '2.4977408e+07',
#   '1709119445160'],
#  ['container_memory_working_set_bytes{container="text-service",namespace="media-microservices",pod="text-service-6949778f76-jwsh9"}',
#   '4.308992e+06',
#   '1709119446661'],
#  ['container_memory_working_set_bytes{container="unique-id-service",namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"}',
#   '4.366336e+06',
#   '1709119446795'],
#  ['container_memory_working_set_bytes{container="user-memcached",namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"}',
#   '4.28032e+06',
#   '1709119445460'],
#  ['container_memory_working_set_bytes{container="user-mongodb",namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"}',
#   '1.7874944e+07',
#   '1709119445620'],
#  ['container_memory_working_set_bytes{container="user-review-mongodb",namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"}',
#   '1.42249984e+08',
#   '1709119445550'],
#  ['container_memory_working_set_bytes{container="user-review-redis",namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"}',
#   '3.44064e+06',
#   '1709119445656'],
#  ['container_memory_working_set_bytes{container="user-review-service",namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"}',
#   '1.241088e+07',
#   '1709119446696'],
#  ['container_memory_working_set_bytes{container="user-service",namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"}',
#   '6.209536e+06',
#   '1709119446715'],
#  ['container_start_time_seconds{container="cast-info-memcached",namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"}',
#   '1.709099225e+09',
#   '1709099225000'],
#  ['container_start_time_seconds{container="cast-info-mongodb",namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"}',
#   '1.709099572e+09',
#   '1709099572000'],
#  ['container_start_time_seconds{container="cast-info-service",namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"}',
#   '1.709099471e+09',
#   '1709099471000'],
#  ['container_start_time_seconds{container="compose-review-memcached",namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"}',
#   '1.709099566e+09',
#   '1709099566000'],
#  ['container_start_time_seconds{container="compose-review-service",namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"}',
#   '1.709099385e+09',
#   '1709099385000'],
#  ['container_start_time_seconds{container="coredns",namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"}',
#   '1.709099055e+09',
#   '1709099055000'],
#  ['container_start_time_seconds{container="etcd",namespace="kube-system",pod="etcd-minikube"}',
#   '1.709099036e+09',
#   '1709099036000'],
#  ['container_start_time_seconds{container="jaeger",namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"}',
#   '1.709099439e+09',
#   '1709099439000'],
#  ['container_start_time_seconds{container="kube-apiserver",namespace="kube-system",pod="kube-apiserver-minikube"}',
#   '1.709099036e+09',
#   '1709099036000'],
#  ['container_start_time_seconds{container="kube-controller-manager",namespace="kube-system",pod="kube-controller-manager-minikube"}',
#   '1.709099036e+09',
#   '1709099036000'],
#  ['container_start_time_seconds{container="kube-proxy",namespace="kube-system",pod="kube-proxy-ht6xb"}',
#   '1.709099054e+09',
#   '1709099054000'],
#  ['container_start_time_seconds{container="kube-scheduler",namespace="kube-system",pod="kube-scheduler-minikube"}',
#   '1.709099036e+09',
#   '1709099036000'],
#  ['container_start_time_seconds{container="kube-state-metrics",namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"}',
#   '1.709105114e+09',
#   '1709105114000'],
#  ['container_start_time_seconds{container="movie-id-memcached",namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"}',
#   '1.709099525e+09',
#   '1709099525000'],
#  ['container_start_time_seconds{container="movie-id-mongodb",namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"}',
#   '1.709099451e+09',
#   '1709099451000'],
#  ['container_start_time_seconds{container="movie-id-service",namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"}',
#   '1.709099446e+09',
#   '1709099446000'],
#  ['container_start_time_seconds{container="movie-info-memcached",namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"}',
#   '1.709099539e+09',
#   '1709099539000'],
#  ['container_start_time_seconds{container="movie-info-mongodb",namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"}',
#   '1.709099497e+09',
#   '1709099497000'],
#  ['container_start_time_seconds{container="movie-info-service",namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"}',
#   '1.709099466e+09',
#   '1709099466000'],
#  ['container_start_time_seconds{container="movie-review-mongodb",namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"}',
#   '1.709099204e+09',
#   '1709099204000'],
#  ['container_start_time_seconds{container="movie-review-redis",namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"}',
#   '1.709099448e+09',
#   '1709099448000'],
#  ['container_start_time_seconds{container="movie-review-service",namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"}',
#   '1.709099457e+09',
#   '1709099457000'],
#  ['container_start_time_seconds{container="nginx-web-server",namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"}',
#   '1.70909969e+09',
#   '1709099690000'],
#  ['container_start_time_seconds{container="page-service",namespace="media-microservices",pod="page-service-54b69789b-6zgfz"}',
#   '1.709099575e+09',
#   '1709099575000'],
#  ['container_start_time_seconds{container="plot-memcached",namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"}',
#   '1.709099463e+09',
#   '1709099463000'],
#  ['container_start_time_seconds{container="plot-mongodb",namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"}',
#   '1.709099443e+09',
#   '1709099443000'],
#  ['container_start_time_seconds{container="plot-service",namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"}',
#   '1.709099454e+09',
#   '1709099454000'],
#  ['container_start_time_seconds{container="rating-redis",namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"}',
#   '1.709099418e+09',
#   '1709099418000'],
#  ['container_start_time_seconds{container="rating-service",namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"}',
#   '1.709099543e+09',
#   '1709099543000'],
#  ['container_start_time_seconds{container="review-storage-memcached",namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"}',
#   '1.709099546e+09',
#   '1709099546000'],
#  ['container_start_time_seconds{container="review-storage-mongodb",namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"}',
#   '1.709099564e+09',
#   '1709099564000'],
#  ['container_start_time_seconds{container="review-storage-service",namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"}',
#   '1.709099508e+09',
#   '1709099508000'],
#  ['container_start_time_seconds{container="storage-provisioner",namespace="kube-system",pod="storage-provisioner"}',
#   '1.709099055e+09',
#   '1709099055000'],
#  ['container_start_time_seconds{container="text-service",namespace="media-microservices",pod="text-service-6949778f76-jwsh9"}',
#   '1.709099561e+09',
#   '1709099561000'],
#  ['container_start_time_seconds{container="unique-id-service",namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"}',
#   '1.709099468e+09',
#   '1709099468000'],
#  ['container_start_time_seconds{container="user-memcached",namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"}',
#   '1.709099555e+09',
#   '1709099555000'],
#  ['container_start_time_seconds{container="user-mongodb",namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"}',
#   '1.709099558e+09',
#   '1709099558000'],
#  ['container_start_time_seconds{container="user-review-mongodb",namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"}',
#   '1.70909946e+09',
#   '1709099460000'],
#  ['container_start_time_seconds{container="user-review-redis",namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"}',
#   '1.709099549e+09',
#   '1709099549000'],
#  ['container_start_time_seconds{container="user-review-service",namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"}',
#   '1.709099569e+09',
#   '1709099569000'],
#  ['container_start_time_seconds{container="user-service",namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"}',
#   '1.709099552e+09',
#   '1709099552000'],
#  ['node_cpu_usage_seconds_total', '42205.399265', '1709119435310'],
#  ['node_memory_working_set_bytes', '3.753668608e+09', '1709119435310'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"}',
#   '22.331737',
#   '1709119442598'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="etcd-minikube"}',
#   '212.514887',
#   '1709119433226'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-apiserver-minikube"}',
#   '545.454658',
#   '1709119441686'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-controller-manager-minikube"}',
#   '166.900228',
#   '1709119443667'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-proxy-ht6xb"}',
#   '5.260428',
#   '1709119435583'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-scheduler-minikube"}',
#   '33.535799',
#   '1709119437223'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"}',
#   '6.4729',
#   '1709119442189'],
#  ['pod_cpu_usage_seconds_total{namespace="kube-system",pod="storage-provisioner"}',
#   '26.049839',
#   '1709119438648'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"}',
#   '1.881703',
#   '1709119441018'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"}',
#   '67.177194',
#   '1709119438431'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"}',
#   '2.322124',
#   '1709119432234'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"}',
#   '69.741296',
#   '1709119438725'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"}',
#   '311.372331',
#   '1709119443407'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"}',
#   '5.52313',
#   '1709119444188'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"}',
#   '15.216402',
#   '1709119438556'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"}',
#   '65.391121',
#   '1709119443877'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"}',
#   '143.286731',
#   '1709119446268'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"}',
#   '1.885052',
#   '1709119441765'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"}',
#   '64.742006',
#   '1709119434417'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"}',
#   '0.51168',
#   '1709119441976'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"}',
#   '190.121581',
#   '1709119441193'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"}',
#   '34.042424',
#   '1709119441170'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"}',
#   '90.586644',
#   '1709119443677'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"}',
#   '172.227432',
#   '1709119446305'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="page-service-54b69789b-6zgfz"}',
#   '0.069255',
#   '1709119435606'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"}',
#   '1.897486',
#   '1709119432143'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"}',
#   '65.064115',
#   '1709119445273'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"}',
#   '0.469358',
#   '1709119431131'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"}',
#   '40.279082',
#   '1709119443084'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"}',
#   '117.761568',
#   '1709119435446'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"}',
#   '1.864729',
#   '1709119440861'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"}',
#   '103.274318',
#   '1709119437440'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"}',
#   '39.479885',
#   '1709119436682'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="text-service-6949778f76-jwsh9"}',
#   '29.056193',
#   '1709119442314'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"}',
#   '41.421847',
#   '1709119444576'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"}',
#   '9.49559',
#   '1709119438868'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"}',
#   '65.627733',
#   '1709119443038'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"}',
#   '187.157494',
#   '1709119436893'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"}',
#   '34.155963',
#   '1709119436633'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"}',
#   '91.419677',
#   '1709119444869'],
#  ['pod_cpu_usage_seconds_total{namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"}',
#   '49.760611',
#   '1709119443945'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="coredns-5dd5756b68-xpdq5"}',
#   '3.5356672e+07',
#   '1709119442598'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="etcd-minikube"}',
#   '5.3366784e+07',
#   '1709119433226'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="kube-apiserver-minikube"}',
#   '2.57605632e+08',
#   '1709119441686'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="kube-controller-manager-minikube"}',
#   '6.5540096e+07',
#   '1709119443667'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="kube-proxy-ht6xb"}',
#   '2.7144192e+07',
#   '1709119435583'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="kube-scheduler-minikube"}',
#   '3.4332672e+07',
#   '1709119437223'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="kube-state-metrics-69dd4877d5-fvwjq"}',
#   '2.0606976e+07',
#   '1709119442189'],
#  ['pod_memory_working_set_bytes{namespace="kube-system",pod="storage-provisioner"}',
#   '2.408448e+07',
#   '1709119438648'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="cast-info-memcached-56b648cb4-274nc"}',
#   '1.753088e+06',
#   '1709119441018'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="cast-info-mongodb-566f5887c-vqzp6"}',
#   '8.1690624e+07',
#   '1709119438431'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="cast-info-service-7ccdbff8-zf45m"}',
#   '1.5597568e+07',
#   '1709119432234'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="compose-review-memcached-598d9dc6cd-cq2dm"}',
#   '1.5773696e+07',
#   '1709119438725'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="compose-review-service-76ccb99f59-dgdcn"}',
#   '1.6699392e+07',
#   '1709119443407'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="jaeger-58bb7ff659-vs6dh"}',
#   '9.7968128e+07',
#   '1709119444188'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-id-memcached-d5c78ff8d-qv8sz"}',
#   '7.471104e+06',
#   '1709119438556'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-id-mongodb-75479f887f-ktrb5"}',
#   '3.8785024e+07',
#   '1709119443877'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-id-service-7d8d47875b-bdz9c"}',
#   '8.298496e+06',
#   '1709119446268'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-info-memcached-6d87c6f986-x25jz"}',
#   '1.531904e+06',
#   '1709119441765'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-info-mongodb-7667c59cb8-tmhrf"}',
#   '2.4915968e+07',
#   '1709119434417'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-info-service-558585d447-55dfn"}',
#   '8.54016e+06',
#   '1709119441976'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-review-mongodb-7d4cdd95d8-bw2fx"}',
#   '1.4092288e+08',
#   '1709119441193'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-review-redis-6d9595df9f-7bb7z"}',
#   '3.559424e+06',
#   '1709119441170'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="movie-review-service-5cd6f6586c-v67md"}',
#   '1.2427264e+07',
#   '1709119443677'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="nginx-web-server-5f7b5f45c4-nbpkz"}',
#   '3.2899072e+07',
#   '1709119446305'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="page-service-54b69789b-6zgfz"}',
#   '1.20832e+06',
#   '1709119435606'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="plot-memcached-556dbfdc46-8c54k"}',
#   '1.536e+06',
#   '1709119432143'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="plot-mongodb-7757d885b8-p8sf8"}',
#   '2.5632768e+07',
#   '1709119445273'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="plot-service-6698596fd4-v24lr"}',
#   '6.08256e+06',
#   '1709119431131'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="rating-redis-75c5f5fd49-shtvz"}',
#   '6.684672e+06',
#   '1709119443084'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="rating-service-7bf447b7f4-t7dtj"}',
#   '1.001472e+07',
#   '1709119435446'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="review-storage-memcached-7b66898b76-r5xr2"}',
#   '1.564672e+06',
#   '1709119440861'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="review-storage-mongodb-f698997c7-bl7cl"}',
#   '2.07343616e+08',
#   '1709119437440'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="review-storage-service-bb48dc4d8-l5wqc"}',
#   '5.214208e+06',
#   '1709119436682'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="text-service-6949778f76-jwsh9"}',
#   '4.698112e+06',
#   '1709119442314'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="unique-id-service-796d5876cc-mkzf8"}',
#   '4.755456e+06',
#   '1709119444576'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="user-memcached-574845dfc8-cj5xg"}',
#   '4.681728e+06',
#   '1709119438868'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="user-mongodb-6964d5bb96-9nrsv"}',
#   '1.6543744e+07',
#   '1709119443038'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="user-review-mongodb-85ccc4bd6f-nx6pm"}',
#   '1.40689408e+08',
#   '1709119436893'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="user-review-redis-558f76b88b-njhbf"}',
#   '3.842048e+06',
#   '1709119436633'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="user-review-service-66659b79cd-vhxwz"}',
#   '1.2529664e+07',
#   '1709119444869'],
#  ['pod_memory_working_set_bytes{namespace="media-microservices",pod="user-service-97d65b7cb-9srq6"}',
#   '6.20544e+06',
#   '1709119443945'],
#  ['scrape_error', '0']]

# %%
containers
# Out:
# {'cast-info-memcached-56b648cb4-274nc': {'namespace': 'media-microservices',
#   'container': 'cast-info-memcached',
#   'pod': 'cast-info-memcached-56b648cb4-274nc',
#   'cpu': '1.831069',
#   'cpu_timestamp': '1709119067945',
#   'memory_timestamp': '1709119059484'},
#  'cast-info-mongodb-566f5887c-vqzp6': {'namespace': 'media-microservices',
#   'container': 'cast-info-mongodb',
#   'pod': 'cast-info-mongodb-566f5887c-vqzp6',
#   'cpu': '65.995307',
#   'cpu_timestamp': '1709119068060',
#   'memory_timestamp': '1709119066777'},
#  'cast-info-service-7ccdbff8-zf45m': {'namespace': 'media-microservices',
#   'container': 'cast-info-service',
#   'pod': 'cast-info-service-7ccdbff8-zf45m',
#   'cpu': '2.297739',
#   'cpu_timestamp': '1709119069107',
#   'memory_timestamp': '1709119053932'},
#  'compose-review-memcached-598d9dc6cd-cq2dm': {'namespace': 'media-microservices',
#   'container': 'compose-review-memcached',
#   'pod': 'compose-review-memcached-598d9dc6cd-cq2dm',
#   'cpu': '69.678921',
#   'cpu_timestamp': '1709119068055',
#   'memory_timestamp': '1709119060966'},
#  'compose-review-service-76ccb99f59-dgdcn': {'namespace': 'media-microservices',
#   'container': 'compose-review-service',
#   'pod': 'compose-review-service-76ccb99f59-dgdcn',
#   'cpu': '311.353522',
#   'cpu_timestamp': '1709119069154',
#   'memory_timestamp': '1709119063330'},
#  'coredns-5dd5756b68-xpdq5': {'namespace': 'kube-system',
#   'container': 'coredns',
#   'pod': 'coredns-5dd5756b68-xpdq5',
#   'cpu': '21.916929',
#   'cpu_timestamp': '1709119067618',
#   'memory_timestamp': '1709119062803'},
#  'etcd-minikube': {'namespace': 'kube-system',
#   'container': 'etcd',
#   'pod': 'etcd-minikube',
#   'cpu': '209.011908',
#   'cpu_timestamp': '1709119067771',
#   'memory_timestamp': '1709119065940'},
#  'jaeger-58bb7ff659-vs6dh': {'namespace': 'media-microservices',
#   'container': 'jaeger',
#   'pod': 'jaeger-58bb7ff659-vs6dh',
#   'cpu': '5.328963',
#   'cpu_timestamp': '1709119067685',
#   'memory_timestamp': '1709119058055'},
#  'kube-apiserver-minikube': {'namespace': 'kube-system',
#   'container': 'kube-apiserver',
#   'pod': 'kube-apiserver-minikube',
#   'cpu': '536.372874',
#   'cpu_timestamp': '1709119067782',
#   'memory_timestamp': '1709119059321'},
#  'kube-controller-manager-minikube': {'namespace': 'kube-system',
#   'container': 'kube-controller-manager',
#   'pod': 'kube-controller-manager-minikube',
#   'cpu': '164.105459',
#   'cpu_timestamp': '1709119067836',
#   'memory_timestamp': '1709119064855'},
#  'kube-proxy-ht6xb': {'namespace': 'kube-system',
#   'container': 'kube-proxy',
#   'pod': 'kube-proxy-ht6xb',
#   'cpu': '5.166801',
#   'cpu_timestamp': '1709119067873',
#   'memory_timestamp': '1709119066914'},
#  'kube-scheduler-minikube': {'namespace': 'kube-system',
#   'container': 'kube-scheduler',
#   'pod': 'kube-scheduler-minikube',
#   'cpu': '32.927702',
#   'cpu_timestamp': '1709119067771',
#   'memory_timestamp': '1709119065876'},
#  'kube-state-metrics-69dd4877d5-fvwjq': {'namespace': 'kube-system',
#   'container': 'kube-state-metrics',
#   'pod': 'kube-state-metrics-69dd4877d5-fvwjq',
#   'cpu': '6.296223',
#   'cpu_timestamp': '1709119067821',
#   'memory_timestamp': '1709119060981'},
#  'movie-id-memcached-d5c78ff8d-qv8sz': {'namespace': 'media-microservices',
#   'container': 'movie-id-memcached',
#   'pod': 'movie-id-memcached-d5c78ff8d-qv8sz',
#   'cpu': '15.148939',
#   'cpu_timestamp': '1709119068077',
#   'memory_timestamp': '1709119068281'},
#  'movie-id-mongodb-75479f887f-ktrb5': {'namespace': 'media-microservices',
#   'container': 'movie-id-mongodb',
#   'pod': 'movie-id-mongodb-75479f887f-ktrb5',
#   'cpu': '64.195311',
#   'cpu_timestamp': '1709119068124',
#   'memory_timestamp': '1709119063496'},
#  'movie-id-service-7d8d47875b-bdz9c': {'namespace': 'media-microservices',
#   'container': 'movie-id-service',
#   'pod': 'movie-id-service-7d8d47875b-bdz9c',
#   'cpu': '143.26239',
#   'cpu_timestamp': '1709119069156',
#   'memory_timestamp': '1709119061348'},
#  'movie-info-memcached-6d87c6f986-x25jz': {'namespace': 'media-microservices',
#   'container': 'movie-info-memcached',
#   'pod': 'movie-info-memcached-6d87c6f986-x25jz',
#   'cpu': '1.836219',
#   'cpu_timestamp': '1709119068036',
#   'memory_timestamp': '1709119065142'},
#  'movie-info-mongodb-7667c59cb8-tmhrf': {'namespace': 'media-microservices',
#   'container': 'movie-info-mongodb',
#   'pod': 'movie-info-mongodb-7667c59cb8-tmhrf',
#   'cpu': '63.573635',
#   'cpu_timestamp': '1709119068096',
#   'memory_timestamp': '1709119067660'},
#  'movie-info-service-558585d447-55dfn': {'namespace': 'media-microservices',
#   'container': 'movie-info-service',
#   'pod': 'movie-info-service-558585d447-55dfn',
#   'cpu': '0.490909',
#   'cpu_timestamp': '1709119068996',
#   'memory_timestamp': '1709119068048'},
#  'movie-review-mongodb-7d4cdd95d8-bw2fx': {'namespace': 'media-microservices',
#   'container': 'movie-review-mongodb',
#   'pod': 'movie-review-mongodb-7d4cdd95d8-bw2fx',
#   'cpu': '188.912813',
#   'cpu_timestamp': '1709119068174',
#   'memory_timestamp': '1709119065672'},
#  'movie-review-redis-6d9595df9f-7bb7z': {'namespace': 'media-microservices',
#   'container': 'movie-review-redis',
#   'pod': 'movie-review-redis-6d9595df9f-7bb7z',
#   'cpu': '33.410939',
#   'cpu_timestamp': '1709119068035',
#   'memory_timestamp': '1709119052997'},
#  'movie-review-service-5cd6f6586c-v67md': {'namespace': 'media-microservices',
#   'container': 'movie-review-service',
#   'pod': 'movie-review-service-5cd6f6586c-v67md',
#   'cpu': '90.564122',
#   'cpu_timestamp': '1709119069138',
#   'memory_timestamp': '1709119057428'},
#  'nginx-web-server-5f7b5f45c4-nbpkz': {'namespace': 'media-microservices',
#   'container': 'nginx-web-server',
#   'pod': 'nginx-web-server-5f7b5f45c4-nbpkz',
#   'cpu': '164.348844',
#   'cpu_timestamp': '1709119068541',
#   'memory_timestamp': '1709119063379'},
#  'page-service-54b69789b-6zgfz': {'namespace': 'media-microservices',
#   'container': 'page-service',
#   'pod': 'page-service-54b69789b-6zgfz',
#   'cpu': '0.050671',
#   'cpu_timestamp': '1709119069085',
#   'memory_timestamp': '1709119065487'},
#  'plot-memcached-556dbfdc46-8c54k': {'namespace': 'media-microservices',
#   'container': 'plot-memcached',
#   'pod': 'plot-memcached-556dbfdc46-8c54k',
#   'cpu': '1.849881',
#   'cpu_timestamp': '1709119068078',
#   'memory_timestamp': '1709119068289'},
#  'plot-mongodb-7757d885b8-p8sf8': {'namespace': 'media-microservices',
#   'container': 'plot-mongodb',
#   'pod': 'plot-mongodb-7757d885b8-p8sf8',
#   'cpu': '63.865193',
#   'cpu_timestamp': '1709119068135',
#   'memory_timestamp': '1709119061912'},
#  'plot-service-6698596fd4-v24lr': {'namespace': 'media-microservices',
#   'container': 'plot-service',
#   'pod': 'plot-service-6698596fd4-v24lr',
#   'cpu': '0.44504',
#   'cpu_timestamp': '1709119069121',
#   'memory_timestamp': '1709119056411'},
#  'rating-redis-75c5f5fd49-shtvz': {'namespace': 'media-microservices',
#   'container': 'rating-redis',
#   'pod': 'rating-redis-75c5f5fd49-shtvz',
#   'cpu': '39.655107',
#   'cpu_timestamp': '1709119067985',
#   'memory_timestamp': '1709119059630'},
#  'rating-service-7bf447b7f4-t7dtj': {'namespace': 'media-microservices',
#   'container': 'rating-service',
#   'pod': 'rating-service-7bf447b7f4-t7dtj',
#   'cpu': '117.742793',
#   'cpu_timestamp': '1709119069164',
#   'memory_timestamp': '1709119057193'},
#  'review-storage-memcached-7b66898b76-r5xr2': {'namespace': 'media-microservices',
#   'container': 'review-storage-memcached',
#   'pod': 'review-storage-memcached-7b66898b76-r5xr2',
#   'cpu': '1.814535',
#   'cpu_timestamp': '1709119068062',
#   'memory_timestamp': '1709119058344'},
#  'review-storage-mongodb-f698997c7-bl7cl': {'namespace': 'media-microservices',
#   'container': 'review-storage-mongodb',
#   'pod': 'review-storage-mongodb-f698997c7-bl7cl',
#   'cpu': '102.097599',
#   'cpu_timestamp': '1709119068094',
#   'memory_timestamp': '1709119056033'},
#  'review-storage-service-bb48dc4d8-l5wqc': {'namespace': 'media-microservices',
#   'container': 'review-storage-service',
#   'pod': 'review-storage-service-bb48dc4d8-l5wqc',
#   'cpu': '39.459892',
#   'cpu_timestamp': '1709119069165',
#   'memory_timestamp': '1709119059874'},
#  'storage-provisioner': {'namespace': 'kube-system',
#   'container': 'storage-provisioner',
#   'pod': 'storage-provisioner',
#   'cpu': '25.558249',
#   'cpu_timestamp': '1709119067676',
#   'memory_timestamp': '1709119063768'},
#  'text-service-6949778f76-jwsh9': {'namespace': 'media-microservices',
#   'container': 'text-service',
#   'pod': 'text-service-6949778f76-jwsh9',
#   'cpu': '29.038444',
#   'cpu_timestamp': '1709119069121',
#   'memory_timestamp': '1709119056960'},
#  'unique-id-service-796d5876cc-mkzf8': {'namespace': 'media-microservices',
#   'container': 'unique-id-service',
#   'pod': 'unique-id-service-796d5876cc-mkzf8',
#   'cpu': '41.401181',
#   'cpu_timestamp': '1709119069135',
#   'memory_timestamp': '1709119052901'},
#  'user-memcached-574845dfc8-cj5xg': {'namespace': 'media-microservices',
#   'container': 'user-memcached',
#   'pod': 'user-memcached-574845dfc8-cj5xg',
#   'cpu': '9.431595',
#   'cpu_timestamp': '1709119067983',
#   'memory_timestamp': '1709119063406'},
#  'user-mongodb-6964d5bb96-9nrsv': {'namespace': 'media-microservices',
#   'container': 'user-mongodb',
#   'pod': 'user-mongodb-6964d5bb96-9nrsv',
#   'cpu': '64.438142',
#   'cpu_timestamp': '1709119068124',
#   'memory_timestamp': '1709119066355'},
#  'user-review-mongodb-85ccc4bd6f-nx6pm': {'namespace': 'media-microservices',
#   'container': 'user-review-mongodb',
#   'pod': 'user-review-mongodb-85ccc4bd6f-nx6pm',
#   'cpu': '185.954124',
#   'cpu_timestamp': '1709119068122',
#   'memory_timestamp': '1709119065478'},
#  'user-review-redis-558f76b88b-njhbf': {'namespace': 'media-microservices',
#   'container': 'user-review-redis',
#   'pod': 'user-review-redis-558f76b88b-njhbf',
#   'cpu': '33.558895',
#   'cpu_timestamp': '1709119068001',
#   'memory_timestamp': '1709119061070'},
#  'user-review-service-66659b79cd-vhxwz': {'namespace': 'media-microservices',
#   'container': 'user-review-service',
#   'pod': 'user-review-service-66659b79cd-vhxwz',
#   'cpu': '91.393472',
#   'cpu_timestamp': '1709119069115',
#   'memory_timestamp': '1709119067988'},
#  'user-service-97d65b7cb-9srq6': {'namespace': 'media-microservices',
#   'container': 'user-service',
#   'pod': 'user-service-97d65b7cb-9srq6',
#   'cpu': '49.73933',
#   'cpu_timestamp': '1709119069134',
#   'memory_timestamp': '1709119068823'}}

# %%
pods
# Out:
# {'coredns-5dd5756b68-xpdq5': {'cpu': '11.362751',
#   'namespace': 'kube-system',
#   'timestamp': '1709109823228',
#   'pod': 'coredns-5dd5756b68-xpdq5',
#   'memory': '3.0539776e+07'},
#  'etcd-minikube': {'cpu': '112.087974',
#   'namespace': 'kube-system',
#   'timestamp': '1709109815866',
#   'pod': 'etcd-minikube',
#   'memory': '8.2300928e+07'},
#  'kube-apiserver-minikube': {'cpu': '288.816945',
#   'namespace': 'kube-system',
#   'timestamp': '1709109824472',
#   'pod': 'kube-apiserver-minikube',
#   'memory': '2.83435008e+08'},
#  'kube-controller-manager-minikube': {'cpu': '85.602686',
#   'namespace': 'kube-system',
#   'timestamp': '1709109816513',
#   'pod': 'kube-controller-manager-minikube',
#   'memory': '6.4032768e+07'},
#  'kube-proxy-ht6xb': {'cpu': '2.988617',
#   'namespace': 'kube-system',
#   'timestamp': '1709109825232',
#   'pod': 'kube-proxy-ht6xb',
#   'memory': '3.4811904e+07'},
#  'kube-scheduler-minikube': {'cpu': '17.420849',
#   'namespace': 'kube-system',
#   'timestamp': '1709109815429',
#   'pod': 'kube-scheduler-minikube',
#   'memory': '3.274752e+07'},
#  'kube-state-metrics-69dd4877d5-fvwjq': {'cpu': '2.155652',
#   'namespace': 'kube-system',
#   'timestamp': '1709109825144',
#   'pod': 'kube-state-metrics-69dd4877d5-fvwjq',
#   'memory': '1.9570688e+07'},
#  'storage-provisioner': {'cpu': '12.864822',
#   'namespace': 'kube-system',
#   'timestamp': '1709109821583',
#   'pod': 'storage-provisioner',
#   'memory': '2.3846912e+07'},
#  'cast-info-memcached-56b648cb4-274nc': {'cpu': '0.980752',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109817292',
#   'pod': 'cast-info-memcached-56b648cb4-274nc',
#   'memory': '3.956736e+06'},
#  'cast-info-mongodb-566f5887c-vqzp6': {'cpu': '33.219555',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811502',
#   'pod': 'cast-info-mongodb-566f5887c-vqzp6',
#   'memory': '2.8041216e+07'},
#  'cast-info-service-7ccdbff8-zf45m': {'cpu': '0.236436',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109820958',
#   'pod': 'cast-info-service-7ccdbff8-zf45m',
#   'memory': '2.674688e+06'},
#  'compose-review-memcached-598d9dc6cd-cq2dm': {'cpu': '0.957332',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109818734',
#   'pod': 'compose-review-memcached-598d9dc6cd-cq2dm',
#   'memory': '2.101248e+06'},
#  'compose-review-service-76ccb99f59-dgdcn': {'cpu': '0.052855',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109826056',
#   'pod': 'compose-review-service-76ccb99f59-dgdcn',
#   'memory': '2.281472e+06'},
#  'jaeger-58bb7ff659-vs6dh': {'cpu': '1.621107',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109812811',
#   'pod': 'jaeger-58bb7ff659-vs6dh',
#   'memory': '2.148352e+07'},
#  'movie-id-memcached-d5c78ff8d-qv8sz': {'cpu': '0.964412',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109814627',
#   'pod': 'movie-id-memcached-d5c78ff8d-qv8sz',
#   'memory': '2.121728e+06'},
#  'movie-id-mongodb-75479f887f-ktrb5': {'cpu': '32.938998',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109823332',
#   'pod': 'movie-id-mongodb-75479f887f-ktrb5',
#   'memory': '3.088384e+07'},
#  'movie-id-service-7d8d47875b-bdz9c': {'cpu': '0.19979',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109810184',
#   'pod': 'movie-id-service-7d8d47875b-bdz9c',
#   'memory': '2.125824e+06'},
#  'movie-info-memcached-6d87c6f986-x25jz': {'cpu': '0.97262',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109815821',
#   'pod': 'movie-info-memcached-6d87c6f986-x25jz',
#   'memory': '3.698688e+06'},
#  'movie-info-mongodb-7667c59cb8-tmhrf': {'cpu': '33.022398',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109822415',
#   'pod': 'movie-info-mongodb-7667c59cb8-tmhrf',
#   'memory': '2.015232e+07'},
#  'movie-info-service-558585d447-55dfn': {'cpu': '0.206244',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109825317',
#   'pod': 'movie-info-service-558585d447-55dfn',
#   'memory': '2.678784e+06'},
#  'movie-review-mongodb-7d4cdd95d8-bw2fx': {'cpu': '34.060742',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811539',
#   'pod': 'movie-review-mongodb-7d4cdd95d8-bw2fx',
#   'memory': '1.974272e+07'},
#  'movie-review-redis-6d9595df9f-7bb7z': {'cpu': '10.938089',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109824364',
#   'pod': 'movie-review-redis-6d9595df9f-7bb7z',
#   'memory': '2.113536e+06'},
#  'movie-review-service-5cd6f6586c-v67md': {'cpu': '0.181612',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109814735',
#   'pod': 'movie-review-service-5cd6f6586c-v67md',
#   'memory': '1.67936e+06'},
#  'nginx-web-server-5f7b5f45c4-nbpkz': {'cpu': '8.161377',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109815477',
#   'pod': 'nginx-web-server-5f7b5f45c4-nbpkz',
#   'memory': '2.7267072e+07'},
#  'page-service-54b69789b-6zgfz': {'cpu': '0.050344',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811853',
#   'pod': 'page-service-54b69789b-6zgfz',
#   'memory': '1.400832e+06'},
#  'plot-memcached-556dbfdc46-8c54k': {'cpu': '0.986347',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109826104',
#   'pod': 'plot-memcached-556dbfdc46-8c54k',
#   'memory': '1.691648e+06'},
#  'plot-mongodb-7757d885b8-p8sf8': {'cpu': '33.161806',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109818553',
#   'pod': 'plot-mongodb-7757d885b8-p8sf8',
#   'memory': '2.2298624e+07'},
#  'plot-service-6698596fd4-v24lr': {'cpu': '0.185386',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109813357',
#   'pod': 'plot-service-6698596fd4-v24lr',
#   'memory': '1.908736e+06'},
#  'rating-redis-75c5f5fd49-shtvz': {'cpu': '10.911292',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109825981',
#   'pod': 'rating-redis-75c5f5fd49-shtvz',
#   'memory': '3.29728e+06'},
#  'rating-service-7bf447b7f4-t7dtj': {'cpu': '0.055129',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109816303',
#   'pod': 'rating-service-7bf447b7f4-t7dtj',
#   'memory': '1.220608e+06'},
#  'review-storage-memcached-7b66898b76-r5xr2': {'cpu': '0.969875',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821926',
#   'pod': 'review-storage-memcached-7b66898b76-r5xr2',
#   'memory': '1.921024e+06'},
#  'review-storage-mongodb-f698997c7-bl7cl': {'cpu': '32.54372',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821812',
#   'pod': 'review-storage-mongodb-f698997c7-bl7cl',
#   'memory': '2.297856e+07'},
#  'review-storage-service-bb48dc4d8-l5wqc': {'cpu': '0.05058',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109819146',
#   'pod': 'review-storage-service-bb48dc4d8-l5wqc',
#   'memory': '2.367488e+06'},
#  'text-service-6949778f76-jwsh9': {'cpu': '0.053976',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109815065',
#   'pod': 'text-service-6949778f76-jwsh9',
#   'memory': '1.425408e+06'},
#  'unique-id-service-796d5876cc-mkzf8': {'cpu': '0.051883',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109823896',
#   'pod': 'unique-id-service-796d5876cc-mkzf8',
#   'memory': '1.101824e+06'},
#  'user-memcached-574845dfc8-cj5xg': {'cpu': '0.98147',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821943',
#   'pod': 'user-memcached-574845dfc8-cj5xg',
#   'memory': '1.695744e+06'},
#  'user-mongodb-6964d5bb96-9nrsv': {'cpu': '32.857544',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109821506',
#   'pod': 'user-mongodb-6964d5bb96-9nrsv',
#   'memory': '2.2765568e+07'},
#  'user-review-mongodb-85ccc4bd6f-nx6pm': {'cpu': '33.335271',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109825939',
#   'pod': 'user-review-mongodb-85ccc4bd6f-nx6pm',
#   'memory': '2.19136e+07'},
#  'user-review-redis-558f76b88b-njhbf': {'cpu': '10.749',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109816533',
#   'pod': 'user-review-redis-558f76b88b-njhbf',
#   'memory': '2.629632e+06'},
#  'user-review-service-66659b79cd-vhxwz': {'cpu': '0.186488',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109808052',
#   'pod': 'user-review-service-66659b79cd-vhxwz',
#   'memory': '1.380352e+06'},
#  'user-service-97d65b7cb-9srq6': {'cpu': '0.050264',
#   'namespace': 'media-microservices',
#   'timestamp': '1709109811483',
#   'pod': 'user-service-97d65b7cb-9srq6',
#   'memory': '1.548288e+06'}}

# %%
import pandas as pd


df = pd.DataFrame(pods.values())
# Out:
# 41
# 41

# %%
# Delete the csv files
import os
os.remove("pods.csv")
os.remove("error_count.csv")
os.remove("containers.csv")
os.remove("nodes.csv")

# %%
import sched, time, os
import pandas as pd
from multiprocessing import Pool

# Create empty csv files

def query_a_node(node_name: str): 
    print("Doing stuff...")

    # Create a dictionary with the data
    pods = {}
    containers = {}
    nodes = {}
    error_count = 0
    response = api_client.call_api(f"/api/v1/nodes/{node_name}/proxy/metrics/resource", "GET", response_type="str")
    data = str(response[0])
    rows = data.split("\n")

    # Remove comments and empty lines
    rows = [row for row in rows if not row.startswith("#") and row.strip() != ""]

    # Split lines from rows
    rows = [row.split() for row in rows]

    for row in rows:
        try:
            if row[0] == "scrape_error":
                error_count = row[1]
            elif row[0][:4] == "node":
                process_node(row, nodes)
            else:
                process_pod_or_container(row, pods, containers)
                
        except IndexError:
            print("Error:",row)

    pods_df = pd.DataFrame(pods.values())
    pods_df.to_csv("pods.csv", mode='a', header=not os.path.exists("pods.csv"), index=False)

    containers_df = pd.DataFrame(containers.values())
    containers_df.to_csv("containers.csv", mode='a', header=not os.path.exists("containers.csv"), index=False)

    nodes_df = pd.DataFrame(nodes.values())
    nodes_df.to_csv("nodes.csv", mode='a', header=not os.path.exists("nodes.csv"), index=False)

    error_count_df = pd.DataFrame({"error_count": [error_count], "timestamp": [time.time()]})
    error_count_df.to_csv("error_count.csv", mode='a', header=not os.path.exists("error_count.csv"), index=False)

    print("Done")

def query_all_nodes(scheduler):
    # schedule the next call first
    scheduler.enter(5, 1, query_all_nodes, (scheduler,))
    pool = Pool(processes=len(node_names))
    for node in node_names:
        pool.apply_async(query_a_node, (node,))
    pool.close()
    pool.join()

my_scheduler = sched.scheduler(time.time, time.sleep)
my_scheduler.enter(0, 1, query_all_nodes, (my_scheduler,))
my_scheduler.run()
# Out:
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# Doing stuff...
# Done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 62
#      60 my_scheduler = sched.scheduler(time.time, time.sleep)
#      61 my_scheduler.enter(0, 1, query_all_nodes, (my_scheduler,))
# ---> 62 my_scheduler.run()
#
# File /usr/lib/python3.11/sched.py:149, in scheduler.run(self, blocking)
#     147     if not blocking:
#     148         return time - now
# --> 149     delayfunc(time - now)
#     150 else:
#     151     action(*argument, **kwargs)
#
# KeyboardInterrupt:

# %%
node_name = "minikube"
import pandas as pd
import os
import time
# Create a dictionary with the data
pods = {}
containers = {}
nodes = {}
error_count = 0
response = api_client.call_api(f"/api/v1/nodes/{node_name}/proxy/metrics/resource", "GET", response_type="str")
data = str(response[0])
rows = data.split("\n")

# Remove comments and empty lines
rows = [row for row in rows if not row.startswith("#") and row.strip() != ""]

# Split lines from rows
rows = [row.split() for row in rows]

for row in rows:
    try:
        if row[0] == "scrape_error":
            error_count = row[1]
        elif row[0][:4] == "node":
            process_node(row, nodes)
        else:
            process_pod_or_container(row, pods, containers)
            
    except IndexError:
        print("Error:",row)

pods_df = pd.DataFrame(pods.values())
pods_df.to_csv("pods.csv", mode='a', header=not os.path.exists("pods.csv"), index=False)

containers_df = pd.DataFrame(containers.values())
containers_df.to_csv("containers.csv", mode='a', header=not os.path.exists("containers.csv"), index=False)

nodes_df = pd.DataFrame(nodes.values())
nodes_df.to_csv("nodes.csv", mode='a', header=not os.path.exists("nodes.csv"), index=False)

error_count_df = pd.DataFrame({"error_count": [error_count], "timestamp": [time.time()]})
error_count_df.to_csv("error_count.csv", mode='a', header=not os.path.exists("error_count.csv"), index=False)

print("Done")
# Out:
# Done

# %%
pods_df
# Out:
#          namespace                                      pod         cpu  \
# 0      kube-system                 coredns-5d78c9869d-lcldh    9.010444
# 1      kube-system                            etcd-minikube   90.535294
# 2      kube-system                  kube-apiserver-minikube  184.354043
# 3      kube-system         kube-controller-manager-minikube   66.695247
# 4      kube-system                         kube-proxy-p8wcq     2.06375
# 5      kube-system                  kube-scheduler-minikube   13.053832
# 6      kube-system          metrics-server-7746886d4f-cnvs4   14.608032
# 7      kube-system                      storage-provisioner    7.651559
# 8   social-network    compose-post-service-866f6d7b74-hl962    0.060319
# 9   social-network     home-timeline-redis-7994f7cb85-d89c9    9.080595
# 10  social-network    home-timeline-service-bbc9bdd7b-cndcg    0.069036
# 11  social-network                  jaeger-7455bdbc47-jchjt    1.430026
# 12  social-network           media-frontend-7f4999dcd-n64xn    10.12433
# 13  social-network         media-memcached-7c887f8cc6-l5q56    0.846595
# 14  social-network            media-mongodb-cb6857b9f-gwf5w   24.067776
# 15  social-network           media-service-7848df64c4-74h8s    0.060424
# 16  social-network            nginx-thrift-57fdb4c4f9-qn6tv    9.503525
# 17  social-network  post-storage-memcached-675b5c57bd-smb49    0.815276
# 18  social-network    post-storage-mongodb-5d7bfcd455-t6sdz   24.290966
# 19  social-network    post-storage-service-84b659876c-7tt26    0.176901
# 20  social-network    social-graph-mongodb-78b95799d7-856w7   24.916022
# 21  social-network      social-graph-redis-7d9b494f66-px74j    9.152051
# 22  social-network    social-graph-service-55b7888dc7-b6jzj    0.172464
# 23  social-network            text-service-76cf6557f7-zxtdn    0.059274
# 24  social-network       unique-id-service-6b88dd4658-fzx7l    0.059433
# 25  social-network   url-shorten-memcached-55d47ccc88-7qv4c    0.810532
# 26  social-network     url-shorten-mongodb-5697666656-cj7vm   24.804824
# 27  social-network     url-shorten-service-6d8bbf75f8-dgrh6    0.169461
# 28  social-network          user-memcached-67b7d46c5b-gsgk4    0.824085
# 29  social-network    user-mention-service-764c7d97c5-7rw64    0.065713
# 30  social-network             user-mongodb-86bb4559d-nmlch   24.590589
# 31  social-network            user-service-74685b9465-8qlhb    0.171282
# 32  social-network   user-timeline-mongodb-687f6576fb-m94rm   24.450529
# 33  social-network     user-timeline-redis-6bf758cc4f-5mndw    9.063566
# 34  social-network   user-timeline-service-65d5766796-2wnnp    0.170668
#
#     cpu_timestamp          memory memory_timestamp
# 0   1712038806142   3.2272384e+07    1712038806142
# 1   1712038811187   8.3206144e+07    1712038811187
# 2   1712038801161  3.48209152e+08    1712038801161
# 3   1712038812912  1.04742912e+08    1712038812912
# 4   1712038808434    3.039232e+07    1712038808434
# 5   1712038805998   5.6971264e+07    1712038805998
# 6   1712038813346   3.0625792e+07    1712038813346
# 7   1712038809859   3.5463168e+07    1712038809859
# 8   1712038811274    1.458176e+06    1712038811274
# 9   1712038796838     7.04512e+06    1712038796838
# 10  1712038808005    1.662976e+06    1712038808005
# 11  1712038801371   1.4364672e+07    1712038801371
# 12  1712038796319   2.4006656e+07    1712038796319
# 13  1712038814005    4.210688e+06    1712038814005
# 14  1712038802504    7.548928e+07    1712038802504
# 15  1712038807931     2.47808e+06    1712038807931
# 16  1712038806384   3.0347264e+07    1712038806384
# 17  1712038800841      4.1984e+06    1712038800841
# 18  1712038804112   7.5137024e+07    1712038804112
# 19  1712038814537    2.248704e+06    1712038814537
# 20  1712038813064  1.05644032e+08    1712038813064
# 21  1712038811366   1.2886016e+07    1712038811366
# 22  1712038805006    4.214784e+06    1712038805006
# 23  1712038808332    2.719744e+06    1712038808332
# 24  1712038800958     1.45408e+06    1712038800958
# 25  1712038812200    2.117632e+06    1712038812200
# 26  1712038811144   6.8001792e+07    1712038811144
# 27  1712038814482     2.31424e+06    1712038814482
# 28  1712038806950    9.048064e+06    1712038806950
# 29  1712038804958    3.178496e+06    1712038804958
# 30  1712038803615     8.57088e+07    1712038803615
# 31  1712038802821    2.318336e+06    1712038802821
# 32  1712038808525   7.5886592e+07    1712038808525
# 33  1712038804337    6.664192e+06    1712038804337
# 34  1712038813060    2.011136e+06    1712038813060
